# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/cars_ds_final.csv',index_col=0)

# %%
df_original=df.copy()

# %%
df
# Out:
#             Make      Model        Variant Ex-Showroom_Price Displacement  \
# 0           Tata  Nano Genx             Xt      Rs. 2,92,667       624 cc
# 1           Tata  Nano Genx             Xe      Rs. 2,36,447       624 cc
# 2           Tata  Nano Genx        Emax Xm      Rs. 2,96,661       624 cc
# 3           Tata  Nano Genx            Xta      Rs. 3,34,768       624 cc
# 4           Tata  Nano Genx             Xm      Rs. 2,72,223       624 cc
# ...          ...        ...            ...               ...          ...
# 1271       Honda       City   Vx Mt Diesel     Rs. 13,02,000      1498 cc
# 1272       Honda       City   Zx Mt Diesel     Rs. 14,21,000      1498 cc
# 1273       Honda       City  Zx Cvt Petrol     Rs. 14,31,000      1497 cc
# 1274       Honda       City   V Cvt Petrol     Rs. 12,01,000      1497 cc
# 1275  Mitsubishi    Montero         3.2 At     Rs. 68,62,560      3200 cc
#
#       Cylinders  Valves_Per_Cylinder               Drivetrain  \
# ...

# %% [markdown]
# # Reading information about data

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1276 entries, 0 to 1275
# Data columns (total 140 columns):
#  #    Column                                     Dtype
# ---   ------                                     -----
#  0    Make                                       object
#  1    Model                                      object
#  2    Variant                                    object
#  3    Ex-Showroom_Price                          object
#  4    Displacement                               object
#  5    Cylinders                                  float64
#  6    Valves_Per_Cylinder                        float64
#  7    Drivetrain                                 object
#  8    Cylinder_Configuration                     object
#  9    Emission_Norm                              object
#  10   Engine_Location                            object
#  11   Fuel_System                                object
#  12   Fuel_Tank_Capacity                         object
# ...

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Variant', 'Ex-Showroom_Price', 'Displacement',
#        'Cylinders', 'Valves_Per_Cylinder', 'Drivetrain',
#        'Cylinder_Configuration', 'Emission_Norm',
#        ...
#        'Leather_Wrapped_Steering', 'Automatic_Headlamps', 'Engine_Type',
#        'ASR_/_Traction_Control', 'Cruise_Control', 'USB_Ports',
#        'Heads-Up_Display', 'Welcome_Lights', 'Battery', 'Electric_Range'],
#       dtype='object', length=140)

# %%
df.describe()
# Out:
#          Cylinders  Valves_Per_Cylinder        Doors  Seating_Capacity  \
# count  1210.000000          1174.000000  1272.000000       1270.000000
# mean      4.380992             3.977853     4.550314          5.270079
# std       1.660957             0.833763     0.747816          1.145231
# min       2.000000             1.000000     2.000000          2.000000
# 25%       4.000000             4.000000     4.000000          5.000000
# 50%       4.000000             4.000000     5.000000          5.000000
# 75%       4.000000             4.000000     5.000000          5.000000
# max      16.000000            16.000000     5.000000         16.000000
#
#        Number_of_Airbags  USB_Ports
# count        1141.000000  29.000000
# mean            3.787029   1.793103
# std             2.522399   0.773642
# min             1.000000   1.000000
# 25%             2.000000   1.000000
# 50%             2.000000   2.000000
# 75%             6.000000   2.000000
# ...

# %%
df.shape
# Out:
# (1276, 140)

# %%
df.isnull().sum()
# Out:
# Make                   75
# Model                   0
# Variant                 0
# Ex-Showroom_Price       0
# Displacement           12
#                      ...
# USB_Ports            1247
# Heads-Up_Display     1225
# Welcome_Lights       1207
# Battery              1263
# Electric_Range       1259
# Length: 140, dtype: int64

# %%
df['Make']
# Out:
# 0             Tata
# 1             Tata
# 2             Tata
# 3             Tata
# 4             Tata
#            ...
# 1271         Honda
# 1272         Honda
# 1273         Honda
# 1274         Honda
# 1275    Mitsubishi
# Name: Make, Length: 1276, dtype: object

# %%
df.head()
# Out:
#    Make      Model  Variant Ex-Showroom_Price Displacement  Cylinders  \
# 0  Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc        2.0
# 1  Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc        2.0
# 2  Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc        2.0
# 3  Tata  Nano Genx      Xta      Rs. 3,34,768       624 cc        2.0
# 4  Tata  Nano Genx       Xm      Rs. 2,72,223       624 cc        2.0
#
#    Valves_Per_Cylinder              Drivetrain Cylinder_Configuration  \
# 0                  2.0  RWD (Rear Wheel Drive)                In-line
# 1                  2.0  RWD (Rear Wheel Drive)                In-line
# 2                  2.0  RWD (Rear Wheel Drive)                In-line
# 3                  2.0  RWD (Rear Wheel Drive)                In-line
# 4                  2.0  RWD (Rear Wheel Drive)                In-line
#
#   Emission_Norm  ... Leather_Wrapped_Steering Automatic_Headlamps Engine_Type  \
# ...

# %%
df.duplicated().value_counts()
# Out:
# False    1267
# True        9
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#             Make      Model        Variant Ex-Showroom_Price Displacement  \
# 0           Tata  Nano Genx             Xt      Rs. 2,92,667       624 cc
# 1           Tata  Nano Genx             Xe      Rs. 2,36,447       624 cc
# 2           Tata  Nano Genx        Emax Xm      Rs. 2,96,661       624 cc
# 3           Tata  Nano Genx            Xta      Rs. 3,34,768       624 cc
# 4           Tata  Nano Genx             Xm      Rs. 2,72,223       624 cc
# ...          ...        ...            ...               ...          ...
# 1271       Honda       City   Vx Mt Diesel     Rs. 13,02,000      1498 cc
# 1272       Honda       City   Zx Mt Diesel     Rs. 14,21,000      1498 cc
# 1273       Honda       City  Zx Cvt Petrol     Rs. 14,31,000      1497 cc
# 1274       Honda       City   V Cvt Petrol     Rs. 12,01,000      1497 cc
# 1275  Mitsubishi    Montero         3.2 At     Rs. 68,62,560      3200 cc
#
#       Cylinders  Valves_Per_Cylinder               Drivetrain  \
# ...

# %%
df.shape
# Out:
# (1276, 140)

# %%
df.describe()
# Out:
#          Cylinders  Valves_Per_Cylinder        Doors  Seating_Capacity  \
# count  1210.000000          1174.000000  1272.000000       1270.000000
# mean      4.380992             3.977853     4.550314          5.270079
# std       1.660957             0.833763     0.747816          1.145231
# min       2.000000             1.000000     2.000000          2.000000
# 25%       4.000000             4.000000     4.000000          5.000000
# 50%       4.000000             4.000000     5.000000          5.000000
# 75%       4.000000             4.000000     5.000000          5.000000
# max      16.000000            16.000000     5.000000         16.000000
#
#        Number_of_Airbags  USB_Ports
# count        1141.000000  29.000000
# mean            3.787029   1.793103
# std             2.522399   0.773642
# min             1.000000   1.000000
# 25%             2.000000   1.000000
# 50%             2.000000   2.000000
# 75%             6.000000   2.000000
# ...

# %%
df.rename(columns=str.lower,inplace=True) #Converting all column names into lower case for easy use.

# %%
df.columns
# Out:
# Index(['make', 'model', 'variant', 'ex-showroom_price', 'displacement',
#        'cylinders', 'valves_per_cylinder', 'drivetrain',
#        'cylinder_configuration', 'emission_norm',
#        ...
#        'leather_wrapped_steering', 'automatic_headlamps', 'engine_type',
#        'asr_/_traction_control', 'cruise_control', 'usb_ports',
#        'heads-up_display', 'welcome_lights', 'battery', 'electric_range'],
#       dtype='object', length=140)

# %% [markdown]
# # Procsessing each column individually

# %% [markdown]
# ### make

# %% [markdown]
# Column contains name of the manufacturer

# %%
df['make']
# Out:
# 0             Tata
# 1             Tata
# 2             Tata
# 3             Tata
# 4             Tata
#            ...
# 1271         Honda
# 1272         Honda
# 1273         Honda
# 1274         Honda
# 1275    Mitsubishi
# Name: make, Length: 1276, dtype: object

# %%
df['make'].isna().sum()
# Out:
# 75

# %%
df[df['make'].isnull()]
# Out:
#      make                    model                  variant ex-showroom_price  \
# 252   NaN    Mercedes-Benz B-Class              B 180 Sport     Rs. 29,88,311
# 253   NaN    Mercedes-Benz B-Class          B 200 Cdi Sport     Rs. 30,89,851
# 254   NaN    Mercedes-Benz B-Class      B 180 Night Edition     Rs. 31,98,662
# 255   NaN    Mercedes-Benz B-Class  B 200 Cdi Night Edition     Rs. 33,03,282
# 256   NaN  Mercedes-Benz Cla-Class                200 Sport     Rs. 35,99,000
# ...   ...                      ...                      ...               ...
# 1151  NaN  Mercedes-Benz Gla-Class          45 Aero Edition     Rs. 80,67,000
# 1219  NaN      Rolls-Royce Phantom                    Sedan   Rs. 9,50,00,000
# 1220  NaN      Rolls-Royce Phantom                      Ewb   Rs. 7,54,00,000
# 1251  NaN        Mercedes-Benz Glc          200 Progressive     Rs. 52,75,000
# 1252  NaN        Mercedes-Benz Glc  220D 4Matic Progressive     Rs. 57,75,000
#
# ...

# %% [markdown]
# Filling null values with appropriate car manufactuerer

# %%
def fill_make_based_on_model(df,model_condition,make_value):
  df.loc[df['model'].str.contains(model_condition, case=False, na=False), 'make'] = make_value
fill_make_based_on_model(df,model_condition='Rolls-Royce',make_value='Rolls-Royce')
fill_make_based_on_model(df,model_condition='Go+',make_value='Datsun ')
fill_make_based_on_model(df,model_condition='Mercedes',make_value='Mercedes')

# %% [markdown]
# All the null vaules has filled with appropriate car manufacturer

# %%
df[df['make'].isnull()]
# Out:
# Empty DataFrame
# ...

# %%
df[880:890]
# Out:
#               make                       model           variant  \
# 880    Rolls-Royce  Rolls-Royce Drophead Coupe           Phantom
# 881  Maruti Suzuki                        Omni       5 Str Bs-Iv
# 882  Maruti Suzuki                        Omni     E 8 Str Bs-Iv
# 883        Datsun                          Go+          Datsun D
# 884        Datsun                          Go+          Datsun T
# 885        Datsun                          Go+      Datsun T (O)
# 886        Datsun                          Go+      Datsun A (O)
# 887        Datsun                          Go+          Datsun A
# 888        Datsun                          Go+      Datsun T Vdc
# 889        Datsun                          Go+  Datsun T (O) Vdc
#
#     ex-showroom_price displacement  cylinders  valves_per_cylinder  \
# 880   Rs. 8,37,55,383      6749 cc       12.0                  4.0
# 881      Rs. 2,82,778       796 cc        3.0                  2.0
# ...

# %%
df['make'].dtype
# Out:
# dtype('O')

# %%
df['make'].value_counts()
# Out:
# Maruti Suzuki       149
# Hyundai             130
# Mahindra            119
# Toyota               82
# Tata                 80
# Datsun               64
# Honda                64
# Mercedes             57
# Skoda                43
# Ford                 37
# Bmw                  37
# Renault              36
# Volkswagen           34
# Audi                 31
# Nissan               29
# Jeep                 28
# Land Rover Rover     27
# Fiat                 23
# Jaguar               22
# Kia                  21
# Volvo                18
# Porsche              14
# Lamborghini          13
# Mg                   13
# Icml                 11
# Mini                 10
# Land Rover           10
# Lexus                10
# Rolls-Royce           9
# Maserati              9
# Ferrari               8
# Mitsubishi            7
# Force                 6
# Bentley               6
# Premier               6
# Isuzu                 5
# Aston Martin          3
# Bugatti               2
# ...

# %% [markdown]
# ### model

# %% [markdown]
# Column contains model of the car.

# %%
df['model']
# Out:
# 0       Nano Genx
# 1       Nano Genx
# 2       Nano Genx
# 3       Nano Genx
# 4       Nano Genx
#           ...
# 1271         City
# 1272         City
# 1273         City
# 1274         City
# 1275      Montero
# Name: model, Length: 1276, dtype: object

# %%
df['model'].isna().sum()
# Out:
# 0

# %%
df['model'].dtype
# Out:
# dtype('O')

# %%
df['model'].value_counts()
# Out:
# Nexon                              24
# Kuv100 Nxt                         22
# Compass                            21
# Xuv500                             21
# Amaze                              20
#                                    ..
# Lc 500H                             1
# Lx 450D                             1
# Mercedes-Benz S-Class Cabriolet     1
# R8                                  1
# Montero                             1
# Name: model, Length: 263, dtype: int64

# %% [markdown]
# ### variant

# %% [markdown]
# Column contains different variants of the car.

# %%
df['variant']
# Out:
# 0                  Xt
# 1                  Xe
# 2             Emax Xm
# 3                 Xta
# 4                  Xm
#             ...
# 1271     Vx Mt Diesel
# 1272     Zx Mt Diesel
# 1273    Zx Cvt Petrol
# 1274     V Cvt Petrol
# 1275           3.2 At
# Name: variant, Length: 1276, dtype: object

# %%
df['variant'].isna().sum()
# Out:
# 0

# %%
df['variant'].dtype
# Out:
# dtype('O')

# %%
df['variant'].value_counts()
# Out:
# Lxi                         9
# Vxi                         9
# Coupe                       8
# S                           7
# V8                          6
#                            ..
# 1.4 Crdi Mt Sx Dual Tone    1
# 1.4 Crdi Mt Sx(O)           1
# Xz                          1
# Xz Plus Dual Tone           1
# 3.2 At                      1
# Name: variant, Length: 1064, dtype: int64

# %% [markdown]
# ### ex-showroom_price

# %% [markdown]
# Contains the Ex-Showroom prices of the car.

# %%
df['ex-showroom_price']
# Out:
# 0        Rs. 2,92,667
# 1        Rs. 2,36,447
# 2        Rs. 2,96,661
# 3        Rs. 3,34,768
# 4        Rs. 2,72,223
#             ...
# 1271    Rs. 13,02,000
# 1272    Rs. 14,21,000
# 1273    Rs. 14,31,000
# 1274    Rs. 12,01,000
# 1275    Rs. 68,62,560
# Name: ex-showroom_price, Length: 1276, dtype: object

# %%
df['ex-showroom_price'].isnull().sum()
# Out:
# 0

# %% [markdown]
# Removing the unecessary charecters in the column by using replace function to convert the type of the elements into integer datatype.

# %%
df['ex-showroom_price']=df['ex-showroom_price'].str.replace(',','')

# %%
df['ex-showroom_price']=df['ex-showroom_price'].str.replace('Rs. ','')
# Out:
# <ipython-input-485-aeb8ddf21e8b>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['ex-showroom_price']=df['ex-showroom_price'].str.replace('Rs. ','')

# %%
df['ex-showroom_price']
# Out:
# 0        292667
# 1        236447
# 2        296661
# 3        334768
# 4        272223
#          ...
# 1271    1302000
# 1272    1421000
# 1273    1431000
# 1274    1201000
# 1275    6862560
# Name: ex-showroom_price, Length: 1276, dtype: object

# %%
df['ex-showroom_price'].dtype
# Out:
# dtype('O')

# %%
df['ex-showroom_price'].astype(int)
# Out:
# 0        292667
# 1        236447
# 2        296661
# 3        334768
# 4        272223
#          ...
# 1271    1302000
# 1272    1421000
# 1273    1431000
# 1274    1201000
# 1275    6862560
# Name: ex-showroom_price, Length: 1276, dtype: int64

# %%
df['ex-showroom_price'].value_counts()
# Out:
# 999900     14
# 999990      4
# 989000      3
# 925000      3
# 745000      3
#            ..
# 698000      1
# 757000      1
# 804000      1
# 838000      1
# 6862560     1
# Name: ex-showroom_price, Length: 1179, dtype: int64

# %% [markdown]
# ### displcement

# %% [markdown]
# Contains information about the displacement of the car.

# %%
df['displacement']=df_original['Displacement']

# %%
df['displacement']
# Out:
# 0        624 cc
# 1        624 cc
# 2        624 cc
# 3        624 cc
# 4        624 cc
#          ...
# 1271    1498 cc
# 1272    1498 cc
# 1273    1497 cc
# 1274    1497 cc
# 1275    3200 cc
# Name: displacement, Length: 1276, dtype: object

# %% [markdown]
# Inorder to convert it into an integer datatype we should remove 'cc' from the column by using replace method.

# %%
df['displacement']=df['displacement'].str.replace('cc','')

# %% [markdown]
# Find if any null values present.

# %%
df['displacement'].isna().sum()
# Out:
# 12

# %% [markdown]
#  We got there are 12 null values.

# %%
df[df['displacement'].isna()]
# Out:
#           make                              model       variant  \
# 615   Mahindra                           E2O Plus            P4
# 616   Mahindra                           E2O Plus            P6
# 617    Datsun                            Tigor Ev           Xm+
# 618    Datsun                            Tigor Ev           Xt+
# 619    Datsun                            Tigor Ev           Xe+
# 745         Mg                              Zs Ev        Excite
# 746         Mg                              Zs Ev     Exclusive
# 862   Mercedes  Mercedes-Benz Amg Gt 4-Door Coupe  63 S 4Matic+
# 1006      Tata                           Nexon Ev            Xm
# 1007      Tata                           Nexon Ev       Xz Plus
# 1008      Tata                           Nexon Ev   Xz Plus Lux
# 1205   Hyundai                      Kona Electric       Premium
#
#      ex-showroom_price displacement  cylinders  valves_per_cylinder  \
# ...

# %% [markdown]
# Replacing the null values as empty.

# %%
df['displacement']=df['displacement'].fillna(df['displacement'].median())

# %%
df['displacement'].isna().sum()
# Out:
# 0

# %%
df['displacement'].dtype
# Out:
# dtype('O')

# %% [markdown]
# Changing data type into float value for using in plotting graphs.

# %%
df['displacement']=df['displacement'].astype(int)

# %%
df.displacement.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 1276 entries, 0 to 1275
# Series name: displacement
# Non-Null Count  Dtype
# --------------  -----
# 1276 non-null   int64
# dtypes: int64(1)
# memory usage: 19.9 KB

# %%
df['displacement'].value_counts()
# Out:
# 1197    108
# 1498     87
# 1497     68
# 1248     62
# 1198     58
#        ...
# 6750      1
# 3198      1
# 2400      1
# 3900      1
# 3200      1
# Name: displacement, Length: 129, dtype: int64

# %%
df[615:619]
# Out:
#          make     model variant ex-showroom_price  displacement  cylinders  \
# 615  Mahindra  E2O Plus      P4            881425          1497        NaN
# 616  Mahindra  E2O Plus      P6            957177          1497        NaN
# 617   Datsun   Tigor Ev     Xm+            960868          1497        NaN
# 618   Datsun   Tigor Ev     Xt+            975868          1497        NaN
#
#      valves_per_cylinder               drivetrain cylinder_configuration  \
# 615                  NaN   RWD (Rear Wheel Drive)                In-line
# 616                  NaN   RWD (Rear Wheel Drive)                In-line
# 617                  NaN  FWD (Front Wheel Drive)                    NaN
# 618                  NaN  FWD (Front Wheel Drive)                    NaN
#
#     emission_norm  ... leather_wrapped_steering automatic_headlamps  \
# 615         BS IV  ...                      NaN                 NaN
# 616         BS IV  ...                      NaN                 NaN
# ...

# %% [markdown]
# ### cylinders

# %% [markdown]
# Contains information about number of cylinders present in a car.

# %%
df['cylinders']
# Out:
# 0       2.0
# 1       2.0
# 2       2.0
# 3       2.0
# 4       2.0
#        ...
# 1271    4.0
# 1272    4.0
# 1273    4.0
# 1274    4.0
# 1275    4.0
# Name: cylinders, Length: 1276, dtype: float64

# %%
df['cylinders'].isnull().sum()
# Out:
# 66

# %%
df[df['cylinders'].isna()]
# Out:
#          make          model                 variant ex-showroom_price  \
# 133   Hyundai           Aura            E 1.2 Petrol            579900
# 134   Hyundai           Aura            S 1.2 Petrol            655900
# 135   Hyundai           Aura        S 1.2 Amt Petrol            705800
# 136   Hyundai           Aura           Sx 1.2 Petrol            729900
# 137   Hyundai           Aura  Sx Plus 1.2 Amt Petrol            804800
# ...       ...            ...                     ...               ...
# 1007     Tata       Nexon Ev                 Xz Plus           1499000
# 1008     Tata       Nexon Ev             Xz Plus Lux           1599000
# 1162   Jaguar         F-Type       5.0 Convertible R          23659454
# 1171    Lexus         Lx 570                      V8          23290000
# 1205  Hyundai  Kona Electric                 Premium           2371858
#
#       displacement  cylinders  valves_per_cylinder               drivetrain  \
# ...

# %%
df[['displacement','cylinders']].drop_duplicates().head(20)
# Out:
#      displacement  cylinders
# 0             624        2.0
# 6             799        3.0
# 10            999        3.0
# 24           1196        4.0
# 29            998        3.0
# 35           1198        3.0
# 46           1086        4.0
# 54           1199        3.0
# 70           1197        4.0
# 81           1173        4.0
# 82           1489        4.0
# 86           1248        4.0
# 89           1364        4.0
# 108          1193        4.0
# 122          1396        4.0
# 133          1197        NaN
# 140           998        NaN
# 141          1186        NaN
# 148          1498        4.0
# 170          1194        3.0

# %%
df['cylinders'].median()
# Out:
# 4.0

# %% [markdown]
# Filling the missing values in cylinders with respect to displacement.

# %%
def fill_cylinders_based_on_displacement(df, displacement_condition, cylinders_value):
    df.loc[df['displacement'] == displacement_condition, 'cylinders'] = cylinders_value
fill_cylinders_based_on_displacement(df,displacement_condition=5000,cylinders_value=6)

# %% [markdown]
# Filling null values by grouping the components in the displacement and cylinders and filling with the median of respective group.

# %%
df['cylinders'] = df.groupby('displacement')['cylinders'].transform(lambda x: x.fillna(x.median()))
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)

# %%
df['cylinders'].isnull().sum()
# Out:
# 6

# %%
df[df['cylinders'].isnull()]
# Out:
#           make        model   variant ex-showroom_price  displacement  \
# 357      Bajaj  Qute (Re60)      Qcar            263000           216
# 358      Bajaj  Qute (Re60)  Qcar Cng            283000           216
# 687   Mahindra     E Verito        D4           1293214            72
# 688   Mahindra     E Verito        D2           1267208            72
# 689   Mahindra     E Verito        D6           1303241            72
# 1171     Lexus       Lx 570        V8          23290000          5700
#
#       cylinders  valves_per_cylinder               drivetrain  \
# 357         NaN                  1.0   RWD (Rear Wheel Drive)
# 358         NaN                  1.0   RWD (Rear Wheel Drive)
# 687         NaN                  NaN  FWD (Front Wheel Drive)
# 688         NaN                  NaN  FWD (Front Wheel Drive)
# 689         NaN                  NaN  FWD (Front Wheel Drive)
# 1171        NaN                  8.0  FWD (Front Wheel Drive)
#
# ...

# %%
df['cylindders']=df['cylinders'].fillna('')

# %%
df['cylindders'].isnull().sum()
# Out:
# 0

# %%
df['cylinders'].dtype
# Out:
# dtype('float64')

# %%
df['cylinders'].value_counts()
# Out:
# 4.0     832
# 3.0     225
# 6.0     112
# 8.0      52
# 12.0     21
# 5.0      10
# 10.0     10
# 2.0       6
# 16.0      2
# Name: cylinders, dtype: int64

# %% [markdown]
# ### valves_per_cylinder

# %% [markdown]
# Contains information about number of valves in a car.

# %%
df['valves_per_cylinder']
# Out:
# 0       2.0
# 1       2.0
# 2       2.0
# 3       2.0
# 4       2.0
#        ...
# 1271    4.0
# 1272    4.0
# 1273    4.0
# 1274    4.0
# 1275    4.0
# Name: valves_per_cylinder, Length: 1276, dtype: float64

# %%
df['valves_per_cylinder'].isnull().sum()
# Out:
# 102

# %%
df[df['valves_per_cylinder'].isnull()]
# Out:
#          make          model                   variant ex-showroom_price  \
# 133   Hyundai           Aura              E 1.2 Petrol            579900
# 134   Hyundai           Aura              S 1.2 Petrol            655900
# 135   Hyundai           Aura          S 1.2 Amt Petrol            705800
# 136   Hyundai           Aura             Sx 1.2 Petrol            729900
# 137   Hyundai           Aura    Sx Plus 1.2 Amt Petrol            804800
# ...       ...            ...                       ...               ...
# 1202   Nissan          Kicks  Xv Premium (O) Dual Tone           1465000
# 1203   Nissan          Kicks                 Xe Diesel            989000
# 1204     Tata         Winger                       15S           1205000
# 1205  Hyundai  Kona Electric                   Premium           2371858
# 1207     Audi             A5                 Sportback           6061200
#
#       displacement  cylinders  valves_per_cylinder               drivetrain  \
# ...

# %%
df['valves_per_cylinder'].median()
# Out:
# 4.0

# %%
df['valves_per_cylinder']=df['valves_per_cylinder'].fillna(df['valves_per_cylinder'].median())

# %%
df['valves_per_cylinder'].isnull().sum()
# Out:
# 0

# %%
df['valves_per_cylinder'].dtype
# Out:
# dtype('float64')

# %%
df['valves_per_cylinder'].value_counts()
# Out:
# 4.0     1215
# 2.0       46
# 12.0       4
# 8.0        4
# 16.0       2
# 1.0        2
# 3.0        2
# 6.0        1
# Name: valves_per_cylinder, dtype: int64

# %% [markdown]
# ### drivetrain

# %% [markdown]
# Contains information about drivetrain

# %%
df['drivetrain']=df_original['Drivetrain'].copy()

# %%
df['drivetrain']
# Out:
# 0        RWD (Rear Wheel Drive)
# 1        RWD (Rear Wheel Drive)
# 2        RWD (Rear Wheel Drive)
# 3        RWD (Rear Wheel Drive)
# 4        RWD (Rear Wheel Drive)
#                  ...
# 1271    FWD (Front Wheel Drive)
# 1272    FWD (Front Wheel Drive)
# 1273    FWD (Front Wheel Drive)
# 1274    FWD (Front Wheel Drive)
# 1275      AWD (All Wheel Drive)
# Name: drivetrain, Length: 1276, dtype: object

# %%
df['drivetrain'].isna().sum()
# Out:
# 7

# %%
df[df['drivetrain'].isna()]
# Out:
#           make                            model            variant  \
# 272       Mini                          Clubman           Cooper S
# 303   Mercedes  Mercedes-Benz E-Class Cabriolet               E400
# 503       Tata                            Nexon                 Xe
# 843   Maserati                           Ghibli             Diesel
# 844   Maserati                           Ghibli          Gransport
# 845   Maserati                           Ghibli          Granlusso
# 1162    Jaguar                           F-Type  5.0 Convertible R
#
#      ex-showroom_price  displacement  cylinders  valves_per_cylinder  \
# 272            4120000          1998        4.0                  4.0
# 303            7711338          2996        6.0                  4.0
# 503             695000          1198        3.0                  4.0
# 843           13387856          2987        6.0                  4.0
# 844           13881858          2987        6.0                  4.0
# ...

# %%
df['drivetrain']=df['drivetrain'].fillna('unknown')

# %%
df['drivetrain'].isna().sum()
# Out:
# 0

# %%
df['drivetrain'].dtype
# Out:
# dtype('O')

# %%
df['drivetrain'].value_counts()
# Out:
# FWD (Front Wheel Drive)    887
# RWD (Rear Wheel Drive)     170
# AWD (All Wheel Drive)      153
# 4WD                         59
# unknown                      7
# Name: drivetrain, dtype: int64

# %% [markdown]
# ###cylinder_configuration

# %% [markdown]
# Contains information about cylinder configuration.

# %%
df['cylinder_configuration']
# Out:
# 0       In-line
# 1       In-line
# 2       In-line
# 3       In-line
# 4       In-line
#          ...
# 1271    In-line
# 1272    In-line
# 1273    In-line
# 1274    In-line
# 1275    In-line
# Name: cylinder_configuration, Length: 1276, dtype: object

# %%
df['cylinder_configuration'].isna().sum()
# Out:
# 13

# %%
df[df['cylinder_configuration'].isna()]
# Out:
#                   make            model                               variant  \
# 388            Hyundai  Grand I10 Prime                            Era T Crdi
# 389            Hyundai  Grand I10 Prime                           Era T+ Crdi
# 617            Datsun          Tigor Ev                                   Xm+
# 618            Datsun          Tigor Ev                                   Xt+
# 619            Datsun          Tigor Ev                                   Xe+
# 687           Mahindra         E Verito                                    D4
# 688           Mahindra         E Verito                                    D2
# 689           Mahindra         E Verito                                    D6
# 833   Land Rover Rover      Range Sport  5.0L V8 Autobiography Dynamic Petrol
# 851   Land Rover Rover            Range    5.0L V8 Svautobiography Lwb Petrol
# 1145        Mitsubishi        Outlander                        2.4L Outlander
# ...

# %%
df['cylinder_configuration']=df['cylinder_configuration'].fillna('unknown')

# %%
df['cylinder_configuration'].isna().sum()
# Out:
# 0

# %%
df['cylinder_configuration'].dtype
# Out:
# dtype('O')

# %%
df['cylinder_configuration'].value_counts()
# Out:
# In-line    1077
# V           176
# unknown      13
# W             6
# Flat          4
# Name: cylinder_configuration, dtype: int64

# %% [markdown]
# ### emission_norm

# %% [markdown]
# Contains information about emission norms

# %%
df['emission_norm']=df_original['Emission_Norm'].copy()

# %%
df['emission_norm']
# Out:
# 0       BS IV
# 1       BS IV
# 2       BS IV
# 3       BS IV
# 4       BS IV
#         ...
# 1271    BS IV
# 1272    BS IV
# 1273     BS 6
# 1274     BS 6
# 1275    BS IV
# Name: emission_norm, Length: 1276, dtype: object

# %%
df['emission_norm'].value_counts()
# Out:
# BS IV     879
# BS 6      358
# BS VI      19
# BS III      9
# Name: emission_norm, dtype: int64

# %% [markdown]
# BS 6 and BS VI are same so it is coverted to BS VI.

# %%
df['emission_norm']=df['emission_norm'].replace('BS 6','BS VI')

# %%
df['emission_norm'].isna().sum()
# Out:
# 11

# %%
df['emission_norm']=df['emission_norm'].fillna('unknown')

# %%
df['emission_norm'].isna().sum()
# Out:
# 0

# %%
df['emission_norm'].value_counts()
# Out:
# BS IV      879
# BS VI      377
# unknown     11
# BS III       9
# Name: emission_norm, dtype: int64

# %%
df['emission_norm'].dtype
# Out:
# dtype('O')

# %% [markdown]
# ### engine_location

# %% [markdown]
# Contains information about the engine location.

# %%
df['engine_location']=df_original['Engine_Location'].copy()

# %%
df['engine_location']
# Out:
# 0          Rear, Transverse
# 1          Rear, Transverse
# 2          Rear, Transverse
# 3          Rear, Transverse
# 4          Rear, Transverse
#                ...
# 1271      Front, Transverse
# 1272      Front, Transverse
# 1273      Front, Transverse
# 1274      Front, Transverse
# 1275    Front, Longitudinal
# Name: engine_location, Length: 1276, dtype: object

# %%
df['engine_location'].isna().sum()
# Out:
# 43

# %% [markdown]
# Replacing null values with unknown.

# %%
df['engine_location']=df['engine_location'].fillna("unknown")

# %%
df['engine_location'].value_counts()
# Out:
# Front, Transverse       804
# Front, Longitudinal     405
# unknown                  43
# Rear, Transverse         16
# Rear Mid, Transverse      3
# Mid, Longitudinal         2
# Mid, Transverse           2
# Rear, Longitudinal        1
# Name: engine_location, dtype: int64

# %%
df['engine_location'].dtype
# Out:
# dtype('O')

# %% [markdown]
# ### fuel_system

# %% [markdown]
# Contains information about fuel system.

# %%
df['fuel_system']
# Out:
# 0       Injection
# 1       Injection
# 2       Injection
# 3       Injection
# 4       Injection
#           ...
# 1271    Injection
# 1272    Injection
# 1273    Injection
# 1274    Injection
# 1275    Injection
# Name: fuel_system, Length: 1276, dtype: object

# %%
df['fuel_system'].isna().sum()
# Out:
# 8

# %%
df['fuel_system'].value_counts()
# Out:
# Injection    1264
# PGM - Fi        4
# Name: fuel_system, dtype: int64

# %% [markdown]
# Most of the fuel systems are fuel injection so if we make null values as fuel injection it wont affect the data much.

# %%
df['fuel_system']=df['fuel_system'].fillna("Injection")

# %%
df['fuel_system'].isna().sum()
# Out:
# 0

# %%
df['fuel_system'].dtype
# Out:
# dtype('O')

# %%
df['fuel_system'].value_counts()
# Out:
# Injection    1272
# PGM - Fi        4
# Name: fuel_system, dtype: int64

# %% [markdown]
# ### fuel_tank_capacity

# %% [markdown]
# Contains information about fuel tank capacity.

# %%
df['fuel_tank_capacity']
# Out:
# 0       24 litres
# 1       24 litres
# 2       15 litres
# 3       24 litres
# 4       24 litres
#           ...
# 1271    40 litres
# 1272    40 litres
# 1273    40 litres
# 1274    40 litres
# 1275    88 litres
# Name: fuel_tank_capacity, Length: 1276, dtype: object

# %%
df['fuel_tank_capacity'].isna().sum()
# Out:
# 69

# %% [markdown]
# Inorder convert it into intger value for plotting graphs we have to remove 'litres' from the column.

# %%
df['fuel_tank_capacity']=df['fuel_tank_capacity'].str.replace(' litres','')

# %%
df['fuel_tank_capacity'].dtype
# Out:
# dtype('O')

# %%
df['fuel_tank_capacity']=df['fuel_tank_capacity'].astype(float)

# %%
df['fuel_tank_capacity'].median()
# Out:
# 46.0

# %% [markdown]
# Replacing null values with median.

# %%
df['fuel_tank_capacity']=df['fuel_tank_capacity'].fillna(df['fuel_tank_capacity'].median())

# %%
df['fuel_tank_capacity'].isna().sum()
# Out:
# 0

# %%
df['fuel_tank_capacity']=df['fuel_tank_capacity'].astype(int)

# %%
df['fuel_tank_capacity'].dtype
# Out:
# dtype('int64')

# %%
df['fuel_tank_capacity'].value_counts()
# Out:
# 45     125
# 35     124
# 50      94
# 60      92
# 37      79
# 46      76
# 55      73
# 40      56
# 42      51
# 70      48
# 44      48
# 43      44
# 80      38
# 66      24
# 90      22
# 32      21
# 28      18
# 75      16
# 52      15
# 63      15
# 41      14
# 48      13
# 85      12
# 93      11
# 27      10
# 82      10
# 47       9
# 62       8
# 64       8
# 68       8
# 56       7
# 100      7
# 78       7
# 67       6
# 65       6
# 105      6
# 54       5
# 24       5
# 51       4
# 89       4
# 86       3
# 83       3
# 88       3
# 57       3
# 61       3
# 58       3
# 73       3
# 74       2
# 71       2
# 91       2
# 76       2
# 92       2
# 15       1
# 96       1
# 87       1
# 36       1
# 72       1
# 59       1
# Name: fuel_tank_capacity, dtype: int64

# %% [markdown]
# ### fuel_type

# %% [markdown]
# Contains information about fuel type.

# %%
df['fuel_type']
# Out:
# 0       Petrol
# 1       Petrol
# 2          CNG
# 3       Petrol
# 4       Petrol
#          ...
# 1271    Diesel
# 1272    Diesel
# 1273    Petrol
# 1274    Petrol
# 1275    Diesel
# Name: fuel_type, Length: 1276, dtype: object

# %%
df['fuel_type'].isna().sum()
# Out:
# 0

# %%
df['fuel_type'].dtype
# Out:
# dtype('O')

# %%
df['fuel_type'].value_counts()
# Out:
# Petrol          643
# Diesel          582
# CNG              16
# Hybrid           15
# Electric         14
# CNG + Petrol      6
# Name: fuel_type, dtype: int64

# %% [markdown]
# ### hieght

# %% [markdown]
# Contains information about height of a car.

# %%
df['height']=df_original['Height'].copy()

# %%
df['height']
# Out:
# 0       1652 mm
# 1       1652 mm
# 2       1652 mm
# 3       1652 mm
# 4       1652 mm
#          ...
# 1271    1495 mm
# 1272    1495 mm
# 1273    1495 mm
# 1274    1495 mm
# 1275    1900 mm
# Name: height, Length: 1276, dtype: object

# %% [markdown]
# Inorder to convert into integer type we have to remove the unit part.

# %%
df['height']=df['height'].str.replace(' mm','')

# %%
df['height']
# Out:
# 0       1652
# 1       1652
# 2       1652
# 3       1652
# 4       1652
#         ...
# 1271    1495
# 1272    1495
# 1273    1495
# 1274    1495
# 1275    1900
# Name: height, Length: 1276, dtype: object

# %%
df['height'].dtype
# Out:
# dtype('O')

# %%
df['height']=df['height'].astype(float)

# %%
df['height'].isnull().sum()
# Out:
# 1

# %%
df['height'].median()
# Out:
# 1557.0

# %%
df['height'] = df['height'].fillna(df.groupby('make')['height'].transform('median'))

# %%
df['height'].isnull().sum()
# Out:
# 0

# %%
df['height']=df['height'].astype(int)

# %%
df['height'].dtype
# Out:
# dtype('int64')

# %%
df['height'].value_counts()
# Out:
# 1520    49
# 1510    35
# 1640    33
# 1560    29
# 1525    27
#         ..
# 1877     1
# 1419     1
# 1705     1
# 1673     1
# 1900     1
# Name: height, Length: 212, dtype: int64

# %% [markdown]
# ### length

# %% [markdown]
# Contains information about length of a car.

# %%
df['length']=df_original['Length'].copy()

# %%
df['length']
# Out:
# 0       3164 mm
# 1       3164 mm
# 2       3164 mm
# 3       3164 mm
# 4       3164 mm
#          ...
# 1271    4440 mm
# 1272    4440 mm
# 1273    4440 mm
# 1274    4440 mm
# 1275    4900 mm
# Name: length, Length: 1276, dtype: object

# %% [markdown]
# Inorder to convert into integer type we have to remove the unit part.

# %%
df['length']=df['length'].str.replace(' mm','')

# %%
df['length'].dtype
# Out:
# dtype('O')

# %%
df['length']=df['length'].astype(float)

# %%
df['length']=df['length'].replace(4.64,df['length'].median())

# %%
df['length']=df['length'].astype(int)

# %%
df['length'].dtype
# Out:
# dtype('int64')

# %%
df['length'].isnull().sum()
# Out:
# 0

# %%
df['length'].value_counts()
# Out:
# 3995    174
# 4440     36
# 4585     29
# 3700     29
# 4395     27
#        ...
# 3987      1
# 5141      1
# 4385      1
# 5285      1
# 4900      1
# Name: length, Length: 227, dtype: int64

# %% [markdown]
# ### width

# %% [markdown]
# Contains information about width of a car.

# %%
df['width']=df_original['Width'].copy()

# %%
df['width']
# Out:
# 0       1750 mm
# 1       1750 mm
# 2       1750 mm
# 3       1750 mm
# 4       1750 mm
#          ...
# 1271    1695 mm
# 1272    1695 mm
# 1273    1695 mm
# 1274    1695 mm
# 1275    1875 mm
# Name: width, Length: 1276, dtype: object

# %% [markdown]
# Inorder to convert into integer type we have to remove the unit part.

# %%
df['width']=df['width'].str.replace(' mm','')

# %%
df['width'].dtype
# Out:
# dtype('O')

# %% [markdown]
# Correcting the wrong element.

# %%
df['width']=df['width'].str.replace('1.845','1845')
# Out:
# <ipython-input-602-a5eee24947fb>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['width']=df['width'].str.replace('1.845','1845')

# %%
df['width'].isnull().sum()
# Out:
# 12

# %%
df['width']=df['width'].astype(float)

# %% [markdown]
# Null values are filled with median of the column.

# %%
df['width']=df['width'].fillna(df['width'].median())

# %%
df['width'].isnull().sum()
# Out:
# 0

# %%
df['width']=df['width'].astype(int)

# %%
df['width'].dtype
# Out:
# dtype('int64')

# %%
df['width'].value_counts()
# Out:
# 1695    76
# 1735    70
# 1730    36
# 1811    30
# 1745    29
#         ..
# 1911     1
# 2034     1
# 2056     1
# 2007     1
# 1875     1
# Name: width, Length: 181, dtype: int64

# %% [markdown]
# ### body_type

# %% [markdown]
# Contains information about body type.

# %%
df['body_type']=df_original['Body_Type'].copy()

# %%
df['body_type']
# Out:
# 0       Hatchback
# 1       Hatchback
# 2       Hatchback
# 3       Hatchback
# 4       Hatchback
#           ...
# 1271        Sedan
# 1272        Sedan
# 1273        Sedan
# 1274        Sedan
# 1275          SUV
# Name: body_type, Length: 1276, dtype: object

# %%
df['body_type'].isna().sum()
# Out:
# 6

# %%
df['body_type']=df['body_type'].fillna("Unknown")

# %%
df['body_type'].isna().sum()
# Out:
# 0

# %%
df['body_type'].dtype
# Out:
# dtype('O')

# %%
df['body_type'].value_counts()
# Out:
# SUV                    447
# Sedan                  333
# Hatchback              316
# Coupe                   41
# MUV                     39
# MPV                     39
# Convertible             20
# Crossover               18
# Unknown                  6
# Sports                   3
# Pick-up                  3
# Sports, Convertible      2
# Sedan, Coupe             2
# Crossover, SUV           2
# SUV, Crossover           2
# Sports, Hatchback        1
# Sedan, Crossover         1
# Coupe, Convertible       1
# Name: body_type, dtype: int64

# %% [markdown]
# ### doors

# %%
df['doors']=df_original['Doors'].copy()

# %% [markdown]
# Contains inforamtion about number of doors.

# %%
df['doors']
# Out:
# 0       5.0
# 1       5.0
# 2       4.0
# 3       5.0
# 4       5.0
#        ...
# 1271    4.0
# 1272    4.0
# 1273    4.0
# 1274    4.0
# 1275    5.0
# Name: doors, Length: 1276, dtype: float64

# %%
df['doors'].isnull().sum()
# Out:
# 4

# %% [markdown]
# Replacing null values with median.

# %%
df['doors'] = df['doors'].fillna(df.groupby('model')['doors'].transform('median'))

# %%
df['doors']=df['doors'].fillna(df['doors'].median())

# %%
df['doors'].isnull().sum()
# Out:
# 0

# %%
df['doors'].dtype
# Out:
# dtype('float64')

# %%
df['doors']=df['doors'].astype(int)

# %%
df['doors'].dtype
# Out:
# dtype('int64')

# %%
df['doors'].value_counts()
# Out:
# 5    840
# 4    362
# 2     62
# 3     12
# Name: doors, dtype: int64

# %% [markdown]
# ### city_mileage

# %%
df['city_mileage']=df_original['City_Mileage'].copy()

# %% [markdown]
# Contains information about city mileage.

# %%
df['city_mileage']
# Out:
# 0       ?23.6 km/litre
# 1       ?23.6 km/litre
# 2                  NaN
# 3       ?23.6 km/litre
# 4       ?23.6 km/litre
#              ...
# 1271     22.6 km/litre
# 1272     22.6 km/litre
# 1273       18 km/litre
# 1274     14.3 km/litre
# 1275     8.25 km/litre
# Name: city_mileage, Length: 1276, dtype: object

# %%
df['city_mileage']=df['city_mileage'].str.replace('?','')
df['city_mileage']=df['city_mileage'].str.replace(' km/litre','')
df['city_mileage']=df['city_mileage'].str.replace(',','.')
df['city_mileage']=df['city_mileage'].str.replace('12.5-12.7','12.6')
df['city_mileage']=df['city_mileage'].str.replace('26032','26.32')
# Out:
# <ipython-input-629-e076f14d29e7>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['city_mileage']=df['city_mileage'].str.replace('?','')
# <ipython-input-629-e076f14d29e7>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['city_mileage']=df['city_mileage'].str.replace('12.5-12.7','12.6')

# %%
df['city_mileage']
# Out:
# 0       23.6
# 1       23.6
# 2        NaN
# 3       23.6
# 4       23.6
#         ...
# 1271    22.6
# 1272    22.6
# 1273      18
# 1274    14.3
# 1275    8.25
# Name: city_mileage, Length: 1276, dtype: object

# %%
df['city_mileage'].dtype
# Out:
# dtype('O')

# %%
df['city_mileage'].astype(float)
# Out:
# 0       23.60
# 1       23.60
# 2         NaN
# 3       23.60
# 4       23.60
#         ...
# 1271    22.60
# 1272    22.60
# 1273    18.00
# 1274    14.30
# 1275     8.25
# Name: city_mileage, Length: 1276, dtype: float64

# %%
df['city_mileage'].isnull().sum()
# Out:
# 555

# %%
df['city_mileage'] = df['city_mileage'].fillna(df.groupby('model')['city_mileage'].transform('median'))
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
# ...

# %%
df['city_mileage'].isnull().sum()
# Out:
# 431

# %% [markdown]
# Replacing null values with median.

# %%
df['city_mileage']=df['city_mileage'].fillna(df['city_mileage'].median())

# %%
df['city_mileage'].isnull().sum()
# Out:
# 0

# %%
df['city_mileage'].value_counts()
# Out:
# 15.29    431
# 12        38
# 16        30
# 18        26
# 14        20
#         ...
# 15.6       1
# 15.71      1
# 18.0       1
# 15.45      1
# 8.25       1
# Name: city_mileage, Length: 191, dtype: int64

# %% [markdown]
# ### highway_mileage

# %% [markdown]
# Contains information about mileage in highways.

# %%
df['highway_mileage']=df_original['Highway_Mileage'].copy()

# %%
df['highway_mileage']
# Out:
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#              ...
# 1271     25.1 km/litre
# 1272     25.1 km/litre
# 1273       18 km/litre
# 1274     16.4 km/litre
# 1275    11.56 km/litre
# Name: highway_mileage, Length: 1276, dtype: object

# %%
df['highway_mileage'].isna().sum()
# Out:
# 800

# %%
df['highway_mileage']=df['highway_mileage'].str.replace(' km/litre','')
df['highway_mileage']=df['city_mileage'].str.replace('8.3-8.4','8.35')
# Out:
# <ipython-input-642-f095e2b45702>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['highway_mileage']=df['city_mileage'].str.replace('8.3-8.4','8.35')

# %%
df['highway_mileage'].astype(float)
# Out:
# 0       23.60
# 1       23.60
# 2         NaN
# 3       23.60
# 4       23.60
#         ...
# 1271    22.60
# 1272    22.60
# 1273    18.00
# 1274    14.30
# 1275     8.25
# Name: highway_mileage, Length: 1276, dtype: float64

# %% [markdown]
# Replacing null values with median.

# %%
df['highway_mileage'] = df['highway_mileage'].fillna(df.groupby('model')['highway_mileage'].transform('median'))
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
# ...

# %%
df['highway_mileage'].isna().sum()
# Out:
# 431

# %%
df['highway_mileage']=df['highway_mileage'].fillna(df['highway_mileage'].median())

# %%
df['highway_mileage'].isna().sum()
# Out:
# 0

# %%
df['highway_mileage'].value_counts()
# Out:
# 15.29    431
# 12        38
# 16        30
# 18        26
# 14        20
#         ...
# 15.6       1
# 15.71      1
# 18.0       1
# 15.45      1
# 8.25       1
# Name: highway_mileage, Length: 191, dtype: int64

# %% [markdown]
# ### arai_certified_mileage

# %% [markdown]
# Contains inforamation about ARAI certified mileage.

# %%
df['arai_certified_mileage']=df_original['ARAI_Certified_Mileage'].copy()

# %%
df['arai_certified_mileage']
# Out:
# 0        23.6 km/litre
# 1        23.6 km/litre
# 2                  NaN
# 3        21.9 km/litre
# 4        23.6 km/litre
#              ...
# 1271     25.1 km/litre
# 1272     25.1 km/litre
# 1273     22.6 km/litre
# 1274     17.8 km/litre
# 1275    11.56 km/litre
# Name: arai_certified_mileage, Length: 1276, dtype: object

# %%
df['arai_certified_mileage'].isna().sum()
# Out:
# 114

# %%
df['arai_certified_mileage']=df['arai_certified_mileage'].str.replace(' km/litre','')
df['arai_certified_mileage']=df['arai_certified_mileage'].str.replace('9.8-10.0','9.9')
df['arai_certified_mileage']=df['arai_certified_mileage'].str.replace('22.4-21.9','23.5')
df['arai_certified_mileage']=df['arai_certified_mileage'].str.replace('10kmpl','10.0')
# Out:
# <ipython-input-652-eab932b94b92>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['arai_certified_mileage']=df['arai_certified_mileage'].str.replace('9.8-10.0','9.9')
# <ipython-input-652-eab932b94b92>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['arai_certified_mileage']=df['arai_certified_mileage'].str.replace('22.4-21.9','23.5')

# %%
df['arai_certified_mileage']
# Out:
# 0        23.6
# 1        23.6
# 2         NaN
# 3        21.9
# 4        23.6
#         ...
# 1271     25.1
# 1272     25.1
# 1273     22.6
# 1274     17.8
# 1275    11.56
# Name: arai_certified_mileage, Length: 1276, dtype: object

# %%
df['arai_certified_mileage'].astype(float)
# Out:
# 0       23.60
# 1       23.60
# 2         NaN
# 3       21.90
# 4       23.60
#         ...
# 1271    25.10
# 1272    25.10
# 1273    22.60
# 1274    17.80
# 1275    11.56
# Name: arai_certified_mileage, Length: 1276, dtype: float64

# %%
median_values = df[df['fuel_type'] != 'CNG'].groupby('model')['arai_certified_mileage'].median()

# Fill null values based on the median values calculated
df['arai_certified_mileage'] = df.apply(
    lambda row: median_values[row['model']] if pd.isnull(row['arai_certified_mileage']) and row['fuel_type'] != 'CNG' else row['arai_certified_mileage'],
    axis=1
)
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
# ...

# %%
df['arai_certified_mileage'].isna().sum()
# Out:
# 61

# %%
overall_median = df[df['fuel_type'] != 'CNG']['arai_certified_mileage'].median()

# Fill null values with the overall median, but avoid filling for rows where 'fuel_type' is 'CNG'
df['arai_certified_mileage'] = df.apply(
    lambda row: overall_median if pd.isnull(row['arai_certified_mileage']) and row['fuel_type'] != 'CNG' else row['arai_certified_mileage'],
    axis=1
)

# %%
df['arai_certified_mileage'].isna().sum()
# Out:
# 16

# %% [markdown]
# We should keep 16 values as null because its fuel type is CNG.

# %%
df['arai_certified_mileage'].value_counts()
# Out:
# 18.16    45
# 23       27
# 17.1     24
# 16       24
# 17.6     23
#          ..
# 14.4      1
# 8.61      1
# 17.97     1
# 10.26     1
# 11.56     1
# Name: arai_certified_mileage, Length: 298, dtype: int64

# %% [markdown]
# ### arai certified mileage for cng

# %%
df['arai_certified_mileage_for_cng']=df_original['ARAI_Certified_Mileage_for_CNG'].copy()

# %% [markdown]
# Conatains information about ARAI certified mileage for CNG.

# %%
df['arai_certified_mileage_for_cng']
# Out:
# 0            NaN
# 1            NaN
# 2       36 km/kg
# 3            NaN
# 4            NaN
#           ...
# 1271         NaN
# 1272         NaN
# 1273         NaN
# 1274         NaN
# 1275         NaN
# Name: arai_certified_mileage_for_cng, Length: 1276, dtype: object

# %%
df['arai_certified_mileage_for_cng']=df['arai_certified_mileage_for_cng'].str.replace(' km/kg','')

# %%
df['arai_certified_mileage_for_cng']
# Out:
# 0       NaN
# 1       NaN
# 2        36
# 3       NaN
# 4       NaN
#        ...
# 1271    NaN
# 1272    NaN
# 1273    NaN
# 1274    NaN
# 1275    NaN
# Name: arai_certified_mileage_for_cng, Length: 1276, dtype: object

# %%
df['arai_certified_mileage_for_cng'].astype(float)
# Out:
# 0        NaN
# 1        NaN
# 2       36.0
# 3        NaN
# 4        NaN
#         ...
# 1271     NaN
# 1272     NaN
# 1273     NaN
# 1274     NaN
# 1275     NaN
# Name: arai_certified_mileage_for_cng, Length: 1276, dtype: float64

# %%
df['arai_certified_mileage_for_cng'].count()
# Out:
# 27

# %%
median_values = df[df['fuel_type'] == 'CNG+Petrol'].groupby('model')['arai_certified_mileage_for_cng'].median()

# Fill null values based on the median values calculated
df['arai_certified_mileage_for_cng'] = df.apply(
    lambda row: median_values[row['model']] if pd.isnull(row['arai_certified_mileage_for_cng']) and row['fuel_type'] == 'CNG+Petrol' else row['arai_certified_mileage_for_cng'],
    axis=1
)

# %%
df.loc[~df['fuel_type'].isin(['CNG', 'CNG+Petrol']), 'arai_certified_mileage_for_cng'] = pd.NA

# %%
df['arai_certified_mileage_for_cng'].value_counts()
# Out:
# 20       2
# 30.48    2
# 25       2
# 33.54    2
# 36       1
# 32.26    1
# 31.76    1
# 26.6     1
# 20.4     1
# 43       1
# 31.79    1
# 18.9     1
# Name: arai_certified_mileage_for_cng, dtype: int64

# %%
df['arai_certified_mileage_for_cng'].isna().sum()
# Out:
# 1260

# %%
df['arai_certified_mileage_for_cng']
# Out:
# 0       <NA>
# 1       <NA>
# 2         36
# 3       <NA>
# 4       <NA>
#         ...
# 1271    <NA>
# 1272    <NA>
# 1273    <NA>
# 1274    <NA>
# 1275    <NA>
# Name: arai_certified_mileage_for_cng, Length: 1276, dtype: object

# %% [markdown]
# ### gears

# %% [markdown]
# Contains information about number of gears present in a car.

# %%
df['gears']
# Out:
# 0       4
# 1       4
# 2       4
# 3       5
# 4       4
#        ..
# 1271    6
# 1272    6
# 1273    5
# 1274    5
# 1275    5
# Name: gears, Length: 1276, dtype: object

# %%
df['gears'].isnull().sum()
# Out:
# 105

# %%
df[df['gears'].isna()]
# Out:
#                make      model               variant ex-showroom_price  \
# 18          Renault       Kwid           Rxt Amt 1.0            463290
# 19          Renault       Kwid       Climber Amt 1.0            484490
# 23          Renault       Kwid   Climber (O) Amt 1.0            492190
# 70    Maruti Suzuki      Ignis         Alpha 1.2 Amt            713898
# 71    Maruti Suzuki      Ignis          Alpha 1.2 Mt            666898
# ...             ...        ...                   ...               ...
# 1216          Lexus    Ls 500H                Luxury          18221000
# 1217          Lexus    Ls 500H          Ultra Luxury          18736000
# 1218          Lexus    Ls 500H              Distinct          19371000
# 1222           Fiat  Punto Evo   Active Multijet 1.3            631292
# 1223           Fiat  Punto Evo  Dynamic Multijet 1.3            692655
#
#       displacement  cylinders  valves_per_cylinder               drivetrain  \
# ...

# %%
df['gears']=df['gears'].str.replace('7 Dual Clutch','7')
df['gears']=df['gears'].str.replace('Single Speed Reduction Gear','6')

# %% [markdown]
# Replacing null values with median.

# %%
df['gears']=df['gears'].astype(float)

# %%
df['gears'].median()
# Out:
# 5.0

# %%
df['gears'].isnull().sum()
# Out:
# 105

# %%
df['gears']=df['gears'].fillna(df['gears'].median())

# %%
df['gears'].isnull().sum()
# Out:
# 0

# %%
df['gears'].dtype
# Out:
# dtype('float64')

# %%
df['gears']=df['gears'].astype(int)

# %%
df['gears'].value_counts()
# Out:
# 5    719
# 6    234
# 8    139
# 7    138
# 9     30
# 4     16
# Name: gears, dtype: int64

# %% [markdown]
# ### ground_clearance

# %%
df['ground_clearance']=df_original['Ground_Clearance'].copy()

# %% [markdown]
# Contains information about ground clearence of a car.

# %%
df['ground_clearance']
# Out:
# 0       180 mm
# 1       180 mm
# 2       180 mm
# 3       180 mm
# 4       180 mm
#          ...
# 1271    165 mm
# 1272    165 mm
# 1273    165 mm
# 1274    165 mm
# 1275    235 mm
# Name: ground_clearance, Length: 1276, dtype: object

# %%
df['ground_clearance'].isnull().sum()
# Out:
# 289

# %%
df['ground_clearance']=df['ground_clearance'].str.replace(' mm','')

# %%
df['ground_clearance']=df['ground_clearance'].astype(float)

# %%
df['ground_clearance'].median()
# Out:
# 170.0

# %% [markdown]
# Replacing null values with median.

# %%
df['ground_clearance']=df['ground_clearance'].fillna(df['ground_clearance'].median())

# %%
df['ground_clearance'].isnull().sum()
# Out:
# 0

# %%
df['ground_clearance'].dtype
# Out:
# dtype('float64')

# %%
df['ground_clearance']=df['ground_clearance'].astype(int)

# %%
df['ground_clearance'].value_counts()
# Out:
# 170    427
# 165    143
# 200     75
# 180     65
# 190     56
#       ...
# 130      1
# 128      1
# 227      1
# 137      1
# 235      1
# Name: ground_clearance, Length: 72, dtype: int64

# %% [markdown]
# ### front_brakes

# %%
df['front_brakes']=df_original['Front_Brakes'].copy()

# %% [markdown]
# Contains information about front brake.

# %%
df['front_brakes']
# Out:
# 0                  Drum
# 1                  Drum
# 2                  Drum
# 3                  Drum
# 4                  Drum
#              ...
# 1271    Ventilated Disc
# 1272    Ventilated Disc
# 1273    Ventilated Disc
# 1274    Ventilated Disc
# 1275    Ventilated Disc
# Name: front_brakes, Length: 1276, dtype: object

# %%
df['front_brakes'].isnull().sum()
# Out:
# 25

# %% [markdown]
# Replacing null values.

# %%
df['front_brakes']=df['front_brakes'].fillna('Unknown')

# %%
df['front_brakes'].isnull().sum()
# Out:
# 0

# %%
df['front_brakes'].dtype
# Out:
# dtype('O')

# %%
df['front_brakes'].value_counts()
# Out:
# Ventilated Disc    1167
# Solid Disc           74
# Unknown              25
# Drum                 10
# Name: front_brakes, dtype: int64

# %% [markdown]
# ### rear_brakes

# %%
df['rear_brakes']=df_original['Rear_Brakes'].copy()

# %% [markdown]
# Contains information about rear brake.

# %%
df['rear_brakes']
# Out:
# 0                  Drum
# 1                  Drum
# 2                  Drum
# 3                  Drum
# 4                  Drum
#              ...
# 1271               Drum
# 1272               Drum
# 1273               Drum
# 1274               Drum
# 1275    Ventilated Disc
# Name: rear_brakes, Length: 1276, dtype: object

# %%
df['rear_brakes'].isnull().sum()
# Out:
# 25

# %% [markdown]
# Replacing null values.

# %%
df['rear_brakes']=df['rear_brakes'].fillna('Unknown')

# %%
df['rear_brakes'].isnull().sum()
# Out:
# 0

# %%
df['rear_brakes'].dtype
# Out:
# dtype('O')

# %%
df['rear_brakes'].value_counts()
# Out:
# Drum               782
# Ventilated Disc    425
# Solid Disc          44
# Unknown             25
# Name: rear_brakes, dtype: int64

# %% [markdown]
# ### power_steering

# %%
df['power_steering']=df_original['Power_Steering'].copy()

# %% [markdown]
# Contains information about power steering.

# %%
df['power_steering']
# Out:
# 0       Electric Power
# 1                  NaN
# 2       Electric Power
# 3       Electric Power
# 4       Electric Power
#              ...
# 1271    Electric Power
# 1272    Electric Power
# 1273    Electric Power
# 1274    Electric Power
# 1275    Electric Power
# Name: power_steering, Length: 1276, dtype: object

# %%
df['power_steering'].isnull().sum()
# Out:
# 57

# %% [markdown]
# Replacing null values.

# %%
df['power_steering']=df['power_steering'].fillna('Unknown')

# %%
df['power_steering'].isnull().sum()
# Out:
# 0

# %%
df['power_steering'].dtype
# Out:
# dtype('O')

# %%
df['power_steering'].value_counts()
# Out:
# Electric Power                     924
# Electro-Hydraulic                  137
# Yes                                 85
# Hydraulic Power                     72
# Unknown                             57
# Electric Power, Hydraulic Power      1
# Name: power_steering, dtype: int64

# %% [markdown]
# ### power_windows

# %%
df['power_windows']=df_original['Power_Windows'].copy()

# %% [markdown]
# Contains information about power windows.

# %%
df['power_windows']
# Out:
# 0       Only Front Windows
# 1                      NaN
# 2                      NaN
# 3       Only Front Windows
# 4                      NaN
#                ...
# 1271           All Windows
# 1272           All Windows
# 1273           All Windows
# 1274           All Windows
# 1275           All Windows
# Name: power_windows, Length: 1276, dtype: object

# %%
df['power_windows'].isnull().sum()
# Out:
# 97

# %% [markdown]
# Replacing null values.

# %%
df['power_windows']=df['power_windows'].fillna('Unknown')

# %%
df['rear_brakes'].isnull().sum()
# Out:
# 0

# %%
df['power_windows'].dtype
# Out:
# dtype('O')

# %%
df['power_windows'].value_counts()
# Out:
# All Windows           1035
# Only Front Windows     144
# Unknown                 97
# Name: power_windows, dtype: int64

# %% [markdown]
# ### keyless_entry

# %%
df['keyless_entry']=df_original['Keyless_Entry'].copy()

# %% [markdown]
# Contains information about keyless entry.

# %%
df['keyless_entry']
# Out:
# 0          Remote
# 1             NaN
# 2             NaN
# 3          Remote
# 4             NaN
#           ...
# 1271    Smart Key
# 1272    Smart Key
# 1273    Smart Key
# 1274       Remote
# 1275          Yes
# Name: keyless_entry, Length: 1276, dtype: object

# %%
df['keyless_entry'].isnull().sum()
# Out:
# 274

# %% [markdown]
# Replacing null values.

# %%
df['keyless_entry']=df['keyless_entry'].fillna('No')

# %%
df['keyless_entry'].isnull().sum()
# Out:
# 0

# %%
df['keyless_entry'].dtype
# Out:
# dtype('O')

# %%
df['keyless_entry'].value_counts()
# Out:
# Smart Key            456
# Remote               421
# No                   274
# Yes                  103
# Remote, Smart Key     21
# Smart Key, Remote      1
# Name: keyless_entry, dtype: int64

# %% [markdown]
# ### power

# %% [markdown]
# Contains information about keyless entry.

# %%
df['power']
# Out:
# 0        38PS@5500rpm
# 1        38PS@5500rpm
# 2        38PS@5500rpm
# 3        38PS@5500rpm
# 4        38PS@5500rpm
#             ...
# 1271    100PS@3600rpm
# 1272    100PS@3600rpm
# 1273    119PS@6600rpm
# 1274    119PS@6600rpm
# 1275    202ps@3800rpm
# Name: power, Length: 1276, dtype: object

# %%
df['power'].isnull().sum()
# Out:
# 0

# %%
df['power'].dtype
# Out:
# dtype('O')

# %%
df['power'].value_counts()
# Out:
# 83PS@6000rpm           52
# 75PS@4000rpm           37
# 90PS@4000rpm           29
# 100PS@3750RPM          28
# 68PS@6000rpm           25
#                        ..
# 248bhp@5200rpm          1
# 268PS@6350rpm           1
# 258bhp@5800-6100rpm     1
# 197hp@4500-6500rpm      1
# 202ps@3800rpm           1
# Name: power, Length: 372, dtype: int64

# %% [markdown]
# ### tourque

# %%
df['torque']=df_original['Torque'].copy()

# %% [markdown]
# Contains information about torque.

# %%
df['torque']
# Out:
# 0        51Nm@4000rpm
# 1        51Nm@4000rpm
# 2        51Nm@4000rpm
# 3        51Nm@4000rpm
# 4        51Nm@4000rpm
#             ...
# 1271    200Nm@1750rpm
# 1272    200Nm@1750rpm
# 1273    145Nm@4600rpm
# 1274    145Nm@4600rpm
# 1275    441Nm@2000rpm
# Name: torque, Length: 1276, dtype: object

# %%
df['torque'].isnull().sum()
# Out:
# 2

# %% [markdown]
# Replacing null values.

# %%
df['torque']=df['torque'].fillna('Unknown')

# %%
df['torque'].isnull().sum()
# Out:
# 0

# %%
df['torque'].dtype
# Out:
# dtype('O')

# %%
df['torque'].value_counts()
# Out:
# 90Nm@3500rpm          42
# 200Nm@1750rpm         42
# 114Nm@4000rpm         27
# 350Nm@1750-2500rpm    26
# 104Nm@4000rpm         22
#                       ..
# 280Nm@1350-4600rpm     1
# 400 Nm @ 1750 RPM      1
# 400NM@1550rpm          1
# 420Nm@1500-3000rpm     1
# 441Nm@2000rpm          1
# Name: torque, Length: 343, dtype: int64

# %% [markdown]
# ### odometer

# %%
df['odometer']=df_original['Odometer'].copy()

# %% [markdown]
# Contains information about odometer.

# %%
df['odometer']
# Out:
# 0       Digital
# 1       Digital
# 2       Digital
# 3       Digital
# 4       Digital
#          ...
# 1271    Digital
# 1272    Digital
# 1273    Digital
# 1274    Digital
# 1275     Analog
# Name: odometer, Length: 1276, dtype: object

# %%
df['odometer'].isnull().sum()
# Out:
# 43

# %% [markdown]
# Replacing null values.

# %%
df['odometer']=df['odometer'].fillna('Unknown')

# %%
df['odometer'].isnull().sum()
# Out:
# 0

# %%
df['odometer'].dtype
# Out:
# dtype('O')

# %%
df['odometer'].value_counts()
# Out:
# Digital            1059
# Analog               90
# Yes                  83
# Unknown              43
# Digital, Analog       1
# Name: odometer, dtype: int64

# %% [markdown]
# ### speedometer

# %%
df['speedometer']=df_original['Speedometer'].copy()

# %% [markdown]
# Contains information about speedometer.

# %%
df['speedometer']
# Out:
# 0                Analog
# 1                Analog
# 2                Analog
# 3                Analog
# 4                Analog
#              ...
# 1271             Analog
# 1272             Analog
# 1273             Analog
# 1274             Analog
# 1275    Analog, Digital
# Name: speedometer, Length: 1276, dtype: object

# %%
df['speedometer'].isnull().sum()
# Out:
# 45

# %% [markdown]
# Replacing null values.

# %%
df['speedometer']=df['speedometer'].fillna('Unknown')

# %%
df['speedometer'].isnull().sum()
# Out:
# 0

# %%
df['speedometer'].dtype
# Out:
# dtype('O')

# %%
df['speedometer'].value_counts()
# Out:
# Analog             982
# Digital            111
# Yes                 79
# Analog, Digital     57
# Unknown             45
# Digital, Analog      2
# Name: speedometer, dtype: int64

# %% [markdown]
# ### seating_capacity

# %%
df['seating_capacity']=df_original['Seating_Capacity'].copy()

# %% [markdown]
# Contains information about seating capacity.

# %%
df['seating_capacity']
# Out:
# 0       4.0
# 1       4.0
# 2       4.0
# 3       4.0
# 4       4.0
#        ...
# 1271    5.0
# 1272    5.0
# 1273    5.0
# 1274    5.0
# 1275    7.0
# Name: seating_capacity, Length: 1276, dtype: float64

# %%
df['seating_capacity'].isnull().sum()
# Out:
# 6

# %% [markdown]
# Replacing null values.

# %%
df['seating_capacity']=df['seating_capacity'].fillna(df['seating_capacity'].median())

# %%
df['seating_capacity'].isnull().sum()
# Out:
# 0

# %%
df['seating_capacity'].dtype
# Out:
# dtype('float64')

# %%
df['seating_capacity']=df['seating_capacity'].astype(int)

# %%
df['seating_capacity'].dtype
# Out:
# dtype('int64')

# %%
df['seating_capacity'].value_counts()
# Out:
# 5     921
# 7     183
# 4      70
# 2      39
# 6      26
# 9      19
# 8      17
# 16      1
# Name: seating_capacity, dtype: int64

# %% [markdown]
# ### type

# %%
df['type']=df_original['Type'].copy()

# %% [markdown]
# Contains information about type of gear box.

# %%
df['type']
# Out:
# 0          Manual
# 1          Manual
# 2          Manual
# 3       Automatic
# 4          Manual
#           ...
# 1271       Manual
# 1272       Manual
# 1273    Automatic
# 1274    Automatic
# 1275    Automatic
# Name: type, Length: 1276, dtype: object

# %%
df['type'].isnull().sum()
# Out:
# 1

# %% [markdown]
# Replacing null values.

# %%
df['type']=df['type'].fillna('Unknown')

# %%
df['type'].isnull().sum()
# Out:
# 0

# %%
df['type'].dtype
# Out:
# dtype('O')

# %%
df['type'].value_counts()
# Out:
# Manual       725
# Automatic    522
# AMT           18
# DCT            7
# CVT            3
# Unknown        1
# Name: type, dtype: int64

# %% [markdown]
# ### basic_warranty

# %%
df['basic_warranty']=df_original['Basic_Warranty'].copy()

# %% [markdown]
# Contains information about basic warranty.

# %%
df['basic_warranty']
# Out:
# 0       2 years /75000 Kms (years/distance whichever c...
# 1       2 years /75000 Kms (years/distance whichever c...
# 2       2 years /75000 Kms (years/distance whichever c...
# 3       2 years /75000 Kms (years/distance whichever c...
# 4       2 years /75000 Kms (years/distance whichever c...
#                               ...
# 1271       2 Years / 40,000 Kms (Whichever comes earlier)
# 1272       2 Years / 40,000 Kms (Whichever comes earlier)
# 1273       2 Years / 40,000 Kms (Whichever comes earlier)
# 1274       2 Years / 40,000 Kms (Whichever comes earlier)
# 1275                                                  NaN
# Name: basic_warranty, Length: 1276, dtype: object

# %%
df['basic_warranty'].isnull().sum()
# Out:
# 440

# %% [markdown]
# Replacing null values.

# %%
df['basic_warranty']=df['basic_warranty'].fillna('Unknown')

# %%
df['basic_warranty'].isnull().sum()
# Out:
# 0

# %%
df['basic_warranty'].dtype
# Out:
# dtype('O')

# %%
df['basic_warranty'].value_counts()
# Out:
# Unknown                                                            440
# 2 years / Unlimited Kms                                            132
# 3 years / Unlimited Kms                                            118
# 2 years /40000 Kms (years/distance whichever comes first)          110
# 3 years /100000 Kms (years/distance whichever comes first)          85
# 3 Years/1,00,000 Kms (Whichever comes earlier)                      77
# 2 Years / 40,000 Kms (Whichever comes earlier)                      54
# 2 Years / 100,000 Kms (whichever comes first)                       51
# 2 years /75000 Kms (years/distance whichever comes first)           31
# 2 years /1,00,000 Kms (years/distance whichever comes first)        30
# 24 months /50000 Kms (whichever comes first)                        20
# 2 years /50000 Kms (years/distance whichever comes first)           18
# 2 Years / 75,000 KM (whichever is earlier)                          17
# ...

# %% [markdown]
# ### boot_space

# %%
df['boot_space']=df_original['Boot_Space'].copy()

# %% [markdown]
# Contains information about bootspace.

# %%
df['boot_space']
# Out:
# 0        110 litres
# 1        110 litres
# 2        110 litres
# 3         94 litres
# 4        110 litres
#            ...
# 1271     510 litres
# 1272     510 litres
# 1273     510 litres
# 1274     510 litres
# 1275    1050 litres
# Name: boot_space, Length: 1276, dtype: object

# %%
df['boot_space'].isnull().sum()
# Out:
# 249

# %%
df['boot_space'] = df['boot_space'].replace('209(All3RowsUp).550(3rdRowFolded)&803(2ndRowand3rdRowFolded) litres', '209')

# %%
df['boot_space']=df['boot_space'].str.replace(' litres','')

# %%
df['boot_space']=df['boot_space'].astype(float)

# %% [markdown]
# Replacing null values.

# %%
df['boot_space']=df['boot_space'].fillna(df['boot_space'].median())

# %%
df['boot_space'].isnull().sum()
# Out:
# 0

# %%
df['boot_space'].dtype
# Out:
# dtype('float64')

# %%
df['boot_space']=df['boot_space'].astype(int)

# %%
df['boot_space'].dtype
# Out:
# dtype('int64')

# %%
df['boot_space'].value_counts()
# Out:
# 375     253
# 350      44
# 475      35
# 460      31
# 510      30
#        ...
# 745       1
# 770       1
# 621       1
# 535       1
# 1050      1
# Name: boot_space, Length: 137, dtype: int64

# %% [markdown]
# ### central_locking

# %%
df['central_locking']=df_original['Central_Locking'].copy()

# %% [markdown]
# Contains information about central locking.

# %%
df['central_locking']
# Out:
# 0       Yes
# 1       NaN
# 2       NaN
# 3       Yes
# 4       NaN
#        ...
# 1271    Yes
# 1272    Yes
# 1273    Yes
# 1274    Yes
# 1275    Yes
# Name: central_locking, Length: 1276, dtype: object

# %%
df['central_locking'].isnull().sum()
# Out:
# 149

# %% [markdown]
# Replacing null values.

# %%
df['central_locking']=df['central_locking'].fillna('No')

# %%
df['central_locking'].isnull().sum()
# Out:
# 0

# %%
df['central_locking'].dtype
# Out:
# dtype('O')

# %%
df['central_locking'].value_counts()
# Out:
# Yes    1127
# No      149
# Name: central_locking, dtype: int64

# %% [markdown]
# ### child_safety_locks

# %%
df['child_safety_locks']=df_original['Child_Safety_Locks'].copy()

# %% [markdown]
# Contains information about child safety locks.

# %%
df['child_safety_locks']
# Out:
# 0       Yes
# 1       Yes
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 1271    Yes
# 1272    Yes
# 1273    Yes
# 1274    Yes
# 1275    Yes
# Name: child_safety_locks, Length: 1276, dtype: object

# %%
df['child_safety_locks'].isnull().sum()
# Out:
# 75

# %% [markdown]
# Replacing null values.

# %%
df['child_safety_locks']=df['child_safety_locks'].fillna('No')

# %%
df['child_safety_locks'].isnull().sum()
# Out:
# 0

# %%
df['child_safety_locks'].dtype
# Out:
# dtype('O')

# %%
df['child_safety_locks'].value_counts()
# Out:
# Yes    1201
# No       75
# Name: child_safety_locks, dtype: int64

# %% [markdown]
# ### ventilation_system

# %%
df['ventilation_system']=df_original['Ventilation_System'].copy()

# %% [markdown]
# Contains information about ventilation system.

# %%
df['ventilation_system']
# Out:
# 0       Manual Air conditioning with cooling and heating
# 1                                                    NaN
# 2                     Air Conditioning with cooling only
# 3       Manual Air conditioning with cooling and heating
# 4                     Air Conditioning with cooling only
#                               ...
# 1271                     Fully automatic climate control
# 1272                     Fully automatic climate control
# 1273                     Fully automatic climate control
# 1274                     Fully automatic climate control
# 1275                     Fully automatic climate control
# Name: ventilation_system, Length: 1276, dtype: object

# %%
df['ventilation_system'].isnull().sum()
# Out:
# 35

# %% [markdown]
# Replacing null values.

# %%
df['ventilation_system']=df['ventilation_system'].fillna('Unknown')

# %%
df['ventilation_system'].isnull().sum()
# Out:
# 0

# %%
df['ventilation_system'].dtype
# Out:
# dtype('O')

# %%
df['ventilation_system'].value_counts()
# Out:
# Fully automatic climate control                                                      487
# Manual Air conditioning with cooling and heating                                     447
# 2 Zone Climate Control                                                               148
# 4 Zone climate control                                                                59
# Unknown                                                                               35
# 3 Zone climate control                                                                35
# Air Conditioning with cooling only                                                    22
# Fully automatic climate control, 2 Zone Climate Control                               10
# Yes                                                                                    8
# Heater, Manual Air conditioning with cooling and heating                               6
# ...

# %% [markdown]
# ### auto-dimming_rear-view_mirror

# %%
df['auto-dimming_rear-view_mirror']=df_original['Auto-Dimming_Rear-View_Mirror'].copy()

# %% [markdown]
# Contains information about auto-dimming rear-view mirror.

# %%
df['auto-dimming_rear-view_mirror']
# Out:
# 0       NaN
# 1       NaN
# 2       Yes
# 3       NaN
# 4       NaN
#        ...
# 1271    Yes
# 1272    Yes
# 1273    Yes
# 1274    Yes
# 1275    NaN
# Name: auto-dimming_rear-view_mirror, Length: 1276, dtype: object

# %%
df['auto-dimming_rear-view_mirror'].isnull().sum()
# Out:
# 620

# %% [markdown]
# Replacing null values.

# %%
df['auto-dimming_rear-view_mirror']=df['auto-dimming_rear-view_mirror'].fillna('No')

# %%
df['auto-dimming_rear-view_mirror'].isnull().sum()
# Out:
# 0

# %%
df['auto-dimming_rear-view_mirror'].dtype
# Out:
# dtype('O')

# %%
df['auto-dimming_rear-view_mirror'].value_counts()
# Out:
# Yes    656
# No     620
# Name: auto-dimming_rear-view_mirror, dtype: int64

# %% [markdown]
# ### 3_point_seat-belt_in_middle_rear_seat

# %%
df['3_point_seat-belt_in_middle_rear_seat']=df_original['3_Point_Seat-Belt_in_Middle_Rear_Seat'].copy()

# %% [markdown]
# Contains information about 3 point seat-belt in middle rear seat.

# %%
df['3_point_seat-belt_in_middle_rear_seat']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 1271    NaN
# 1272    NaN
# 1273    NaN
# 1274    NaN
# 1275    NaN
# Name: 3_point_seat-belt_in_middle_rear_seat, Length: 1276, dtype: object

# %%
df['3_point_seat-belt_in_middle_rear_seat'].isnull().sum()
# Out:
# 1225

# %% [markdown]
# Replacing null values.

# %%
df['3_point_seat-belt_in_middle_rear_seat']=df['3_point_seat-belt_in_middle_rear_seat'].fillna('No')

# %%
df['3_point_seat-belt_in_middle_rear_seat'].isnull().sum()
# Out:
# 0

# %%
df['3_point_seat-belt_in_middle_rear_seat'].dtype
# Out:
# dtype('O')

# %%
df['3_point_seat-belt_in_middle_rear_seat'].value_counts()
# Out:
# No     1225
# Yes      51
# Name: 3_point_seat-belt_in_middle_rear_seat, dtype: int64

# %% [markdown]
# ### passenger_side_seat-belt_reminder

# %%
df['passenger_side_seat-belt_reminder']=df_original['Passenger_Side_Seat-Belt_Reminder'].copy()

# %% [markdown]
# Contains information about passenger side seat-belt reminder.

# %%
df['passenger_side_seat-belt_reminder']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 1271    Yes
# 1272    Yes
# 1273    Yes
# 1274    Yes
# 1275    NaN
# Name: passenger_side_seat-belt_reminder, Length: 1276, dtype: object

# %%
df['passenger_side_seat-belt_reminder'].isnull().sum()
# Out:
# 1105

# %% [markdown]
# Replacing null values.

# %%
df['passenger_side_seat-belt_reminder']=df['passenger_side_seat-belt_reminder'].fillna('No')

# %%
df['passenger_side_seat-belt_reminder'].isnull().sum()
# Out:
# 0

# %%
df['passenger_side_seat-belt_reminder'].dtype
# Out:
# dtype('O')

# %%
df['passenger_side_seat-belt_reminder'].value_counts()
# Out:
# No     1105
# Yes     171
# Name: passenger_side_seat-belt_reminder, dtype: int64

# %% [markdown]
# ### abs_(anti-lock_braking_system)

# %%
df['abs_(anti-lock_braking_system)']=df_original['ABS_(Anti-lock_Braking_System)'].copy()

# %% [markdown]
# Contains information about abs (anti-lock braking system).

# %%
df['abs_(anti-lock_braking_system)']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 1271    Yes
# 1272    Yes
# 1273    Yes
# 1274    Yes
# 1275    Yes
# Name: abs_(anti-lock_braking_system), Length: 1276, dtype: object

# %%
df['abs_(anti-lock_braking_system)'].isnull().sum()
# Out:
# 132

# %% [markdown]
# Replacing null values.

# %%
df['abs_(anti-lock_braking_system)']=df['abs_(anti-lock_braking_system)'].fillna('No')

# %%
df['abs_(anti-lock_braking_system)'].isnull().sum()
# Out:
# 0

# %%
df['abs_(anti-lock_braking_system)'].dtype
# Out:
# dtype('O')

# %%
df['abs_(anti-lock_braking_system)'].value_counts()
# Out:
# Yes    1144
# No      132
# Name: abs_(anti-lock_braking_system), dtype: int64

# %% [markdown]
# ### number_of_airbags

# %%
df['number_of_airbags']=df_original['Number_of_Airbags'].copy()

# %% [markdown]
# Contains information about number of airbags.

# %%
df['number_of_airbags']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 1271    2.0
# 1272    6.0
# 1273    6.0
# 1274    2.0
# 1275    6.0
# Name: number_of_airbags, Length: 1276, dtype: float64

# %%
df['number_of_airbags'].isnull().sum()
# Out:
# 135

# %% [markdown]
# Replacing null values.

# %%
df['number_of_airbags']=df['number_of_airbags'].fillna(df['number_of_airbags'].median())

# %%
df['number_of_airbags'].isnull().sum()
# Out:
# 0

# %%
df['number_of_airbags'].dtype
# Out:
# dtype('float64')

# %%
df['number_of_airbags'].value_counts()
# Out:
# 2.0     762
# 6.0     202
# 8.0      92
# 7.0      65
# 1.0      57
# 4.0      40
# 9.0      21
# 3.0      17
# 10.0     16
# 14.0      3
# 5.0       1
# Name: number_of_airbags, dtype: int64

# %% [markdown]
# ### parking_assistance

# %%
df['parking_assistance']=df_original['Parking_Assistance'].copy()

# %% [markdown]
# Contains information about parking assistance.

# %%
df['parking_assistance']
# Out:
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#                        ...
# 1271    Front and rear sensors with camera
# 1272              Rear sensors with camera
# 1273              Rear sensors with camera
# 1274    Front and rear sensors with camera
# 1275              Rear sensors with camera
# Name: parking_assistance, Length: 1276, dtype: object

# %%
df['parking_assistance'].isnull().sum()
# Out:
# 290

# %% [markdown]
# Replacing null values.

# %%
df['parking_assistance']=df['parking_assistance'].fillna('Unknown')

# %%
df['parking_assistance'].isnull().sum()
# Out:
# 0

# %%
df['parking_assistance'].dtype
# Out:
# dtype('O')

# %%
df['parking_assistance'].value_counts()
# Out:
# Rear sensors with camera                                                         367
# Unknown                                                                          290
# Rear sensors                                                                     277
# Front and rear sensors with camera                                               181
# Front & rear sensors with 360 degree view                                        120
# Rear sensors, Rear sensors with camera                                            17
# Yes                                                                               15
# Front sensors, Rear sensors                                                        5
# Front and rear sensors with camera, Front & rear sensors with 360 degree view      2
# Rear sensors with camera, Rear sensors                                             1
# Rear sensors, Front sensors                                                        1
# Name: parking_assistance, dtype: int64

# %% [markdown]
# ### automatic_headlamps

# %%
df['automatic_headlamps']=df_original['Automatic_Headlamps'].copy()

# %% [markdown]
# Contains information about automatic headlamps.

# %%
df['automatic_headlamps']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 1271    NaN
# 1272    Yes
# 1273    Yes
# 1274    NaN
# 1275    NaN
# Name: automatic_headlamps, Length: 1276, dtype: object

# %%
df['automatic_headlamps'].isnull().sum()
# Out:
# 774

# %% [markdown]
# Replacing null values.

# %%
df['automatic_headlamps']=df['automatic_headlamps'].fillna('No')

# %%
df['automatic_headlamps'].isnull().sum()
# Out:
# 0

# %%
df['automatic_headlamps'].dtype
# Out:
# dtype('O')

# %%
df['automatic_headlamps'].value_counts()
# Out:
# No     774
# Yes    502
# Name: automatic_headlamps, dtype: int64

# %% [markdown]
# ### battery

# %%
df['battery']=df_original['Battery'].copy()

# %% [markdown]
# Contains information about battery.

# %%
df['battery']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 1271    NaN
# 1272    NaN
# 1273    NaN
# 1274    NaN
# 1275    NaN
# Name: battery, Length: 1276, dtype: object

# %%
df['battery'].isnull().sum()
# Out:
# 1263

# %% [markdown]
# Replacing null values.

# %%
df['battery']=df['battery'].fillna('Unknown')

# %%
df['battery'].isnull().sum()
# Out:
# 0

# %%
df['battery'].dtype
# Out:
# dtype('O')

# %%
df['battery'].value_counts()
# Out:
# Unknown                                                                                  1263
# 21.5 kWh,Battery Placed Under Rear Seats                                                    3
# 200 ampere-hour                                                                             3
# 30.2 kWh* Advanced Li-ion polymer, liquid cooled battery pack with IP67 certification       3
# 210 ampere-hour                                                                             2
# 44.5 (kWh), Lithium Ion                                                                     2
# Name: battery, dtype: int64

# %% [markdown]
# ### electric_range

# %%
df['electric_range']=df_original['Electric_Range'].copy()

# %% [markdown]
# Contains information about electric_range.

# %%
df['electric_range']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 1271    NaN
# 1272    NaN
# 1273    NaN
# 1274    NaN
# 1275    NaN
# Name: electric_range, Length: 1276, dtype: object

# %%
df['electric_range'].isnull().sum()
# Out:
# 1259

# %% [markdown]
# Replacing null values.

# %%
df['electric_range']=df['electric_range'].fillna('Unknown')

# %%
df['electric_range'].isnull().sum()
# Out:
# 0

# %%
df['electric_range'].dtype
# Out:
# dtype('O')

# %%
df['electric_range'].value_counts()
# Out:
# Unknown                 1259
# 110 km/full charge         5
# 213 km/full charge         3
# 340 km/full charge         2
# 11.68 km/full charge       2
# 312 km/full charge         2
# 39.53 km/full charge       1
# 300 km/full charge         1
# 462 km/full charge         1
# Name: electric_range, dtype: int64

# %% [markdown]
# ## Converting into csv file.

# %%
df.to_csv(r'C:\Users\user\OneDrive\Desktop\raees\internship\week 6\indian cars\cleaned_data_of_indian_cars.csv')

# %% [markdown]
# # Data Visualisation

# %%
df_new=pd.read_csv(r'/content/C__Users_user_OneDrive_Desktop_raees_internship_week 6_indian cars_cleaned_data_of_indian_cars.csv',index_col=0)

# %%
df_new
# Out:
#             make      model        variant  ex-showroom_price  displacement  \
# 0           Tata  Nano Genx             Xt             292667           624
# 1           Tata  Nano Genx             Xe             236447           624
# 2           Tata  Nano Genx        Emax Xm             296661           624
# 3           Tata  Nano Genx            Xta             334768           624
# 4           Tata  Nano Genx             Xm             272223           624
# ...          ...        ...            ...                ...           ...
# 1271       Honda       City   Vx Mt Diesel            1302000          1498
# 1272       Honda       City   Zx Mt Diesel            1421000          1498
# 1273       Honda       City  Zx Cvt Petrol            1431000          1497
# 1274       Honda       City   V Cvt Petrol            1201000          1497
# 1275  Mitsubishi    Montero         3.2 At            6862560          3200
#
# ...

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ## Barplot

# %% [markdown]
# ### Top 10 Car Manufacturers by Number of Cars.

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x=df_new['make'].value_counts().head(10).index,
            y=df_new['make'].value_counts().head(10), palette='viridis')
plt.xlabel('Manufacturers')
plt.ylabel('Number of Cars Made')
plt.title('Top 10 Car Manufacturers by Number of Cars')
plt.xticks(rotation=45)

plt.show()
# Out:
# <ipython-input-876-341bcdcb28e1>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df_new['make'].value_counts().head(10).index,

# %% [markdown]
# **Insights:**
#
#
# *  Maruthi Suzuki produces more cars.

# %% [markdown]
# ### Cars Count by Fuel Types.

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=df_new['fuel_type'].value_counts().index,y=df_new['fuel_type'].value_counts(),palette='viridis')
plt.title('Cars Count by Fuel Types')
plt.xlabel('Fuel Type')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# <ipython-input-877-990c2f92f7bb>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df_new['fuel_type'].value_counts().index,y=df_new['fuel_type'].value_counts(),palette='viridis')

# %% [markdown]
# **Insights:**
#
#
# *  Most vehicles primarily use petrol as the fuel type, followed by diesel.

# %% [markdown]
# ### Sales across different category

# %% [markdown]
# ## Histogram

# %% [markdown]
# ### Based on emission norm

# %%
sns.histplot(df_new['emission_norm'])
# Out:
# <Axes: xlabel='emission_norm', ylabel='Count'>

# %% [markdown]
# **Insights:**
#
#
# * Most cars are equipped with BS VI emission standards.

# %% [markdown]
# ### Histogram of Selected Body Types

# %%
df_new['body_type'].unique()
# Out:
# array(['Hatchback', 'MPV', 'MUV', 'SUV', 'Sedan', 'Crossover', 'Unknown',
#        'Coupe', 'Convertible', 'Sports, Hatchback', 'Sedan, Coupe',
#        'Sports', 'Crossover, SUV', 'SUV, Crossover', 'Sedan, Crossover',
#        'Sports, Convertible', 'Pick-up', 'Coupe, Convertible'],
#       dtype=object)

# %%
selected_body_types = ['Hatchback', 'MPV', 'MUV', 'SUV', 'Sedan', 'Crossover', 'Unknown', 'Coupe', 'Convertible', 'Sports', 'Pick-up']

filtered_df = df_new[df_new['body_type'].isin(selected_body_types)]

plt.figure(figsize=(12, 6))
sns.histplot(filtered_df['body_type'], bins=len(selected_body_types), palette='viridis')
plt.title('Histogram of Selected Body Types')
plt.xlabel('Body Type')
plt.ylabel('Count')

plt.show()
# Out:
# <ipython-input-880-06579861e845>:6: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(filtered_df['body_type'], bins=len(selected_body_types), palette='viridis')

# %% [markdown]
# **Insights:**
#
#
# *  The SUV is the preferred body type in the Indian car market.

# %% [markdown]
# ### Distribution of Drivetrain Types.

# %%
plt.figure(figsize=(12,6))
sns.histplot(df['drivetrain'],bins=20,kde=True)
plt.title('Distribution of Drivetrain Types')
plt.xlabel('Drivetrain Type')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Insights:**
#
#
# *  Front Wheel Drive (FWD) is more dominant on Indian roads.

# %% [markdown]
# ## Pie chart

# %% [markdown]
# ### Distribution of Top 10 Car Models

# %%
model_counts = df_new['model'].value_counts().head(10)
palette_color = sns.color_palette('colorblind', n_colors=len(model_counts))
max_index = model_counts.idxmax()
myexplode = [0.1 if idx == max_index else 0 for idx in model_counts.index]
plt.figure(figsize=(10, 10))
plt.pie(model_counts, labels=model_counts.index, autopct='%1.1f%%', startangle=140, colors=palette_color, explode=myexplode)
plt.title('Distribution of Top 10 Car Models')
plt.show()

# %% [markdown]
# **Insights:**
#
#
# * When examining the top 10 car models in the Indian market, the Nexon has a stronger presence or advantage.

# %% [markdown]
# ### Distribution of Electric Cars Across Car Makes.

# %%
electric_cars = df_new[df_new['fuel_type'] == 'Electric']
electric_car_counts = electric_cars['make'].value_counts() # Count the occurrences of each car make producing electric cars
palette_color = sns.color_palette('viridis', n_colors=len(electric_car_counts))
most_producing_make = electric_car_counts.idxmax() # Find the car make that produces the most electric cars
myexplode = [0.1 if make == most_producing_make else 0 for make in electric_car_counts.index]
plt.figure(figsize=(15, 10))
plt.pie(electric_car_counts, labels=electric_car_counts.index, autopct='%1.1f%%',
        startangle=140, colors=palette_color, explode=myexplode, wedgeprops=dict(width=0.3), labeldistance=0.85)
plt.title('Distribution of Electric Cars Across Car Makes')
plt.show()

# %% [markdown]
# **Insights:**
#
#
# * When examining the presence of electric cars on Indian roads, Mahindra & Mahindra has a more significant representation with a variety of electric models.

# %% [markdown]
# ## Boxplot

# %% [markdown]
# ### Boxplot of Number of Airbags

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x=df['number_of_airbags'], palette='viridis')
plt.title('Boxplot of Number of Airbags')
plt.xlabel('Number of Airbags')
plt.show()
# Out:
# <ipython-input-897-0586eabe2563>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df['number_of_airbags'], palette='viridis')

# %% [markdown]
# ### Boxplot of Fuel Tank Capacity

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x=df['fuel_tank_capacity'], color='red')
plt.title('Boxplot of Fuel Tank Capacity')
plt.xlabel('Fuel Tank Capacity')
plt.show()

# %% [markdown]
# ## Countplot

# %% [markdown]
# ### Count Plot of `Top 10 Maruti Suzuki Models

# %%
maruti_df = df_new[df_new['make'] == 'Maruti Suzuki']
top_10_maruti_models = maruti_df['model'].value_counts().head(10).index
top_10_maruti_models_df = maruti_df[maruti_df['model'].isin(top_10_maruti_models)]
ordered_models = top_10_maruti_models_df['model'].value_counts().index

# Create a count plot
plt.figure(figsize=(12, 6))
sns.countplot(x='model', data=top_10_maruti_models_df, order=ordered_models, palette='viridis')
plt.title('Count Plot of Top 10 Maruti Suzuki Models')
plt.xlabel('Maruti Suzuki Models')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# <ipython-input-909-064bc8194caf>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='model', data=top_10_maruti_models_df, order=ordered_models, palette='viridis')

# %% [markdown]
# **Insights:**
#
#
# * Among Maruti Suzuki's car models, the Dzire, Swift, and Ciaz are among the most favored or highest-selling models.

# %% [markdown]
# ### Top 10 Car Makes by Average City Mileage

# %%
mean_city_mileage = df_new.groupby('make')['city_mileage'].mean().sort_values(ascending=False)

# Select the top 10 car makes
top_10_makes = mean_city_mileage.head(10)

# Create a bar plot for the top 10 car makes
plt.figure(figsize=(12, 6))
sns.barplot(x=top_10_makes.index, y=top_10_makes.values, palette='viridis')
plt.title('Top 10 Car Makes by Average City Mileage')
plt.xlabel('Car Make')
plt.ylabel('Average City Mileage')
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# <ipython-input-921-bf21392736ad>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_10_makes.index, y=top_10_makes.values, palette='viridis')

# %% [markdown]
# **Insights:**
#
#
# * Renault, Maruti Suzuki, Mahindra, and Datsun offer better city mileage compared to other manufacturers, with Renault having a slight advantage in this aspect.

# %% [markdown]
# ### Count Plot of Car Types

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='type', data=df_new, palette='viridis', order=df_new['type'].value_counts().index)
plt.title('Count Plot of Car Types')
plt.xlabel('Car Type')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# <ipython-input-922-74d45a6edd20>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='type', data=df_new, palette='viridis', order=df_new['type'].value_counts().index)

# %% [markdown]
# **Insights:**
#
#
# * The manual transmission is the most preferred car type.

# %% [markdown]
# # Bivariate Analysis:

# %% [markdown]
# ## Top 10 States by Sales

# %%
top_states = df_new.groupby('state')['sales'].sum().sort_values(ascending=False).round(2).head(10)
top_states.plot.barh(color=sns.color_palette('colorblind'))
plt.gca().invert_yaxis()
plt.xlabel('Sales')
plt.ylabel('States')
plt.title('Top 10 States by Sales')
plt.show()

# %% [markdown]
# **Insights:**
#
#
# *  Most of the sales or orders originated from the state of California.

# %% [markdown]
# ## Heatmap

# %%
df_new.corr()

# %%
sns.heatmap(df_new.corr(numeric_only=True),annot=True)

# %% [markdown]
# ### Correlation Matrix Heatmap

# %%
corr_matrix=df_new.corr(numeric_only=True)
corr_matrix

# %%
sns.heatmap(corr_matrix,annot=True,xticklabels=False)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# ## Ship modes choosen by customers

# %%
shipmode_and_customers_df=df_new.groupby('ship mode').sum(numeric_only=True).sort_values('sales',ascending=False)
shipmode_and_customers_df=shipmode_and_customers_df[['sales']]
shipmode_and_customers_df['count']=df['ship mode'].value_counts()
shipmode_and_customers_df.reset_index(inplace=True)
plt.pie(shipmode_and_customers_df['sales'],labels=shipmode_and_customers_df['ship mode'],autopct='%1.2f%%',startangle=235,wedgeprops={'edgecolor':'black','linewidth':0.5})
plt.title('Ship modes choosen by customers')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insights:**
#
#
# * Most of the customers have chosen the standard class as the preferred shipping mode.

# %% [markdown]
# ## Category wise sales of products in different regions

# %%
plt.figure(figsize=(12,6))
category=df_new.groupby(['region','category'],as_index=False).agg({'sales':'sum'})
category.head
sns.barplot(data=category,x='region',y='sales',hue='category')

# %% [markdown]
# **Insights:**
#
#
# * When examining category-wise sales of products across different regions, it becomes apparent that technology dominates in every region. Additionally, the western side exhibits a higher number of orders or sales.

# %% [markdown]
# ## Sales by Sub-Category

# %%
plt.figure(figsize=(25,8))
sns.barplot(data=df_new,x='sub-category',y='sales',errorbar=None,palette='viridis')
plt.title('Sales by Sub-Category')
plt.xlabel('Sub-Category')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# **Insights:**
#
#
# * Copiers are the most ordered items in the sub-category.

# %% [markdown]
# ## Category sales trneds across region

# %%
plt.figure(figsize=(20,8))
sns.lineplot(data=df_new,x='region',y='sales',hue='category',errorbar=None,palette='viridis')
plt.title('Category sales trneds across region')
plt.xlabel('region')
plt.ylabel('Sales')
plt.legend(title='Category',loc='upper left',bbox_to_anchor=(1,1))
plt.show()

# %% [markdown]
# ## Sales over time

# %%
df_new['order date']=pd.to_datetime(df_new['order date'])
df_new['month']=df_new['order date'].dt.month
df_new['quarter']=df_new['order date'].dt.quarter
df_new['year']=df_new['order date'].dt.year
sales_data_monthly=df_new.groupby('month')['sales'].sum().reset_index()
sales_data_quarterly=df_new.groupby('quarter')['sales'].sum().reset_index()
sales_data_yearly=df_new.groupby('year')['sales'].sum().reset_index()

# %% [markdown]
# ### Monthly Sales Variation

# %%
sns.lineplot(data=sales_data_monthly,x='month',y='sales',marker='o',color='blue')
plt.title("Monthly Sales Variation")
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.grid()
plt.show()

# %% [markdown]
# **Insights:**
#
#
# *Most of the sales occurred during the year-end.

# %% [markdown]
# ### Quarterly Sales Variation

# %%
sns.lineplot(data=sales_data_quarterly,x='quarter',y='sales',marker='o',color='red')
plt.title("Quarterly Sales Variation")
plt.xlabel('Quarter')
plt.ylabel('Total Sales')
plt.grid()
plt.show()

# %% [markdown]
# **Insights:**
#
#
# * Most of the sales occurred during the last quarter of the year-end.

# %% [markdown]
# ### Yearly Sales Variation

# %%
sns.lineplot(data=sales_data_yearly,x='year',y='sales',marker='o',color='green')
plt.title("Yearly Sales Variation")
plt.xlabel('Year')
plt.ylabel('Total Sales')
plt.grid()
plt.show()

# %% [markdown]
# **Insights:**
#
#
# * Most of the sales occurred in 2018.

# %% [markdown]
# ## Customer Segment analysis across different regions.

# %%
segment_yearly_sales=df_new.groupby(['segment','year'])['sales'].sum().reset_index()
sns.barplot(data=df_new,x='year',y='sales',errorbar=None,hue='segment',palette='viridis')
plt.title('Sales trends for different segments')
plt.xlabel('Year')
plt.ylabel('Total Sales')
plt.legend(title='Segment',bbox_to_anchor=(1.05,1),loc='upper left')
plt.show()

# %% [markdown]
# **Insights:**
#
#
# * In 2015, the Home Office segment experienced higher sales.
# * In 2016, the Consumer segment saw increased sales.
# * In 2017, the Corporate segment recorded higher sales.
# * In 2018, both the Home Office and Corporate segments were comparable, with
#    the Corporate segment having a slight advantage in sales.

# %% [markdown]
# ## Scatter Plot: Sales vs Postel Code

# %%
plt.figure(figsize=(10, 6))

# Use seaborn scatterplot to create the scatter plot
sns.scatterplot(x='postal code', y='sales', data=df_new, color='blue', alpha=0.7)

# Set labels and title
plt.title('Scatter Plot: Sales vs Postel Code')
plt.xlabel('Postel Code')
plt.ylabel('Sales')

# Show the plot
plt.show()

# %% [markdown]
# ## Pair Plot of Numeric Variables

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'sales', 'quantity', and 'profit' are columns in df_new DataFrame
# If you have different variable names, replace them accordingly
numeric_variables = ['sales','year','quarter','month','postal code']

# Use seaborn pairplot to create the pair plot
sns.pairplot(df_new[numeric_variables])

# Set title
plt.suptitle('Pair Plot of Numeric Variables', y=1.02)

# Show the plot
plt.show()

# %% [markdown]
# ## Pair Plot of Numeric Variables with Region as Hue

# %%
numeric_variables = ['sales', 'year', 'quarter', 'month', 'postal code']
numeric_all_variables = numeric_variables + ['region']
sns.pairplot(df_new[numeric_all_variables], hue='region')
plt.suptitle('Pair Plot of Numeric Variables with Region as Hue', y=1.02)
plt.show()

# %% [markdown]
# ## Top 10 Products by Sales
#
# ---

# %%
top_10_products = df_new.groupby('product name')['sales'].sum().nlargest(10).index
df_top_10 = df_new[df_new['product name'].isin(top_10_products)].sort_values(by='sales', ascending=True)
plt.figure(figsize=(12, 6))
sns.barplot(x='product name', y='sales', errorbar=None,data=df_top_10, palette='viridis')
plt.title('Top 10 Products by Sales (Ascending Order)')
plt.xlabel('Product Name')
plt.ylabel('Sales')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# ## Region-wise Product Sales for Top 10 Products

# %%
top_10_products = df_new.groupby('product name')['sales'].sum().nlargest(10).index
df_top_10 = df_new[df_new['product name'].isin(top_10_products)]
plt.figure(figsize=(12, 6))
sns.barplot(x='product name', y='sales', hue='region',errorbar=None, data=df_top_10, palette='viridis')
plt.title('Region-wise Product Sales for Top 10 Products')
plt.xlabel('Product Name')
plt.ylabel('Sales')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Region', loc='upper left', bbox_to_anchor=(1, 1))
plt.show()
